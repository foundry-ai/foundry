# %%
# %load_ext autoreload
# %autoreload 2
# %aimport -jax
# %aimport -jaxlib

# %%
import stanza.datasets as datasets

# %%
train = datasets.load("celeb_a", splits=("train"))

# %%
from stanza.util.ipython import display_images
display_images(train[:13])

# %%
from jax.random import PRNGKey

key = PRNGKey(0)
train = train.shuffle(key)
display_images(train[:13])
