# %%
# %load_ext autoreload
# %autoreload 2
# %aimport -jax
# %aimport -jaxlib

# %%
import jax
import jax.numpy as jnp
import chex
import numpy as np
from flax import struct
from functools import partial
from typing import Optional, Tuple, Union, Any
from gymnax.environments import environment, spaces
from brax import envs
from brax.envs.wrappers.training import EpisodeWrapper, AutoResetWrapper

class GymnaxWrapper(object):
    """Base class for Gymnax wrappers."""

    def __init__(self, env):
        self._env = env

    # provide proxy access to regular attributes of wrapped object
    def __getattr__(self, name):
        return getattr(self._env, name)

class FlattenObservationWrapper(GymnaxWrapper):
    """Flatten the observations of the environment."""

    def __init__(self, env: environment.Environment):
        super().__init__(env)

    def observation_space(self, params) -> spaces.Box:
        assert isinstance(
            self._env.observation_space(params), spaces.Box
        ), "Only Box spaces are supported for now."
        return spaces.Box(
            low=self._env.observation_space(params).low,
            high=self._env.observation_space(params).high,
            shape=(np.prod(self._env.observation_space(params).shape),),
            dtype=self._env.observation_space(params).dtype,
        )

    @partial(jax.jit, static_argnums=(0,))
    def reset(
        self, key: chex.PRNGKey, params: Optional[environment.EnvParams] = None
    ) -> Tuple[chex.Array, environment.EnvState]:
        obs, state = self._env.reset(key, params)
        obs = jnp.reshape(obs, (-1,))
        return obs, state

    @partial(jax.jit, static_argnums=(0,))
    def step(
        self,
        key: chex.PRNGKey,
        state: environment.EnvState,
        action: Union[int, float],
        params: Optional[environment.EnvParams] = None,
    ) -> Tuple[chex.Array, environment.EnvState, float, bool, dict]:
        obs, state, reward, done, info = self._env.step(key, state, action, params)
        obs = jnp.reshape(obs, (-1,))
        return obs, state, reward, done, info


@struct.dataclass
class LogEnvState:
    env_state: environment.EnvState
    episode_returns: float
    episode_lengths: int
    returned_episode_returns: float
    returned_episode_lengths: int
    timestep: int


class LogWrapper(GymnaxWrapper):
    """Log the episode returns and lengths."""

    def __init__(self, env: environment.Environment):
        super().__init__(env)

    @partial(jax.jit, static_argnums=(0,))
    def reset(
        self, key: chex.PRNGKey, params: Optional[environment.EnvParams] = None
    ) -> Tuple[chex.Array, environment.EnvState]:
        obs, env_state = self._env.reset(key, params)
        state = LogEnvState(env_state, 0, 0, 0, 0, 0)
        return obs, state

    @partial(jax.jit, static_argnums=(0,))
    def step(
        self,
        key: chex.PRNGKey,
        state: environment.EnvState,
        action: Union[int, float],
        params: Optional[environment.EnvParams] = None,
    ) -> Tuple[chex.Array, environment.EnvState, float, bool, dict]:
        obs, env_state, reward, done, info = self._env.step(
            key, state.env_state, action, params
        )
        new_episode_return = state.episode_returns + reward
        new_episode_length = state.episode_lengths + 1
        state = LogEnvState(
            env_state=env_state,
            episode_returns=new_episode_return * (1 - done),
            episode_lengths=new_episode_length * (1 - done),
            returned_episode_returns=state.returned_episode_returns * (1 - done)
            + new_episode_return * done,
            returned_episode_lengths=state.returned_episode_lengths * (1 - done)
            + new_episode_length * done,
            timestep=state.timestep + 1,
        )
        info["returned_episode_returns"] = state.returned_episode_returns
        info["returned_episode_lengths"] = state.returned_episode_lengths
        info["timestep"] = state.timestep
        info["returned_episode"] = done
        return obs, state, reward, done, info


class BraxGymnaxWrapper:
    def __init__(self, env_name, backend="positional"):
        env = envs.get_environment(env_name=env_name, backend=backend)
        env = EpisodeWrapper(env, episode_length=1000, action_repeat=1)
        env = AutoResetWrapper(env)
        self._env = env
        self.action_size = env.action_size
        self.observation_size = (env.observation_size,)

    def reset(self, key, params=None):
        state = self._env.reset(key)
        return state.obs, state

    def step(self, key, state, action, params=None):
        next_state = self._env.step(state, action)
        return next_state.obs, next_state, next_state.reward, next_state.done > 0.5, {}

    def observation_space(self, params):
        return spaces.Box(
            low=-jnp.inf,
            high=jnp.inf,
            shape=(self._env.observation_size,),
        )

    def action_space(self, params):
        return spaces.Box(
            low=-1.0,
            high=1.0,
            shape=(self._env.action_size,),
        )


class ClipAction(GymnaxWrapper):
    def __init__(self, env, low=-1.0, high=1.0):
        super().__init__(env)
        self.low = low
        self.high = high

    def step(self, key, state, action, params=None):
        """TODO: In theory the below line should be the way to do this."""
        # action = jnp.clip(action, self.env.action_space.low, self.env.action_space.high)
        action = jnp.clip(action, self.low, self.high)
        return self._env.step(key, state, action, params)


class TransformObservation(GymnaxWrapper):
    def __init__(self, env, transform_obs):
        super().__init__(env)
        self.transform_obs = transform_obs

    def reset(self, key, params=None):
        obs, state = self._env.reset(key, params)
        return self.transform_obs(obs), state

    def step(self, key, state, action, params=None):
        obs, state, reward, done, info = self._env.step(key, state, action, params)
        return self.transform_obs(obs), state, reward, done, info

class TransformReward(GymnaxWrapper):
    def __init__(self, env, transform_reward):
        super().__init__(env)
        self.transform_reward = transform_reward

    def step(self, key, state, action, params=None):
        obs, state, reward, done, info = self._env.step(key, state, action, params)
        return obs, state, self.transform_reward(reward), done, info


class VecEnv(GymnaxWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.reset = jax.vmap(self._env.reset, in_axes=(0, None))
        self.step = jax.vmap(self._env.step, in_axes=(0, 0, 0, None))


@struct.dataclass
class NormalizeVecObsEnvState:
    mean: jnp.ndarray
    var: jnp.ndarray
    count: float
    env_state: environment.EnvState


class NormalizeVecObservation(GymnaxWrapper):
    def __init__(self, env):
        super().__init__(env)

    def reset(self, key, params=None):
        obs, state = self._env.reset(key, params)
        state = NormalizeVecObsEnvState(
            mean=jnp.zeros_like(obs),
            var=jnp.ones_like(obs),
            count=1e-4,
            env_state=state,
        )
        batch_mean = jnp.mean(obs, axis=0)
        batch_var = jnp.var(obs, axis=0)
        batch_count = obs.shape[0]

        delta = batch_mean - state.mean
        tot_count = state.count + batch_count

        new_mean = state.mean + delta * batch_count / tot_count
        m_a = state.var * state.count
        m_b = batch_var * batch_count
        M2 = m_a + m_b + jnp.square(delta) * state.count * batch_count / tot_count
        new_var = M2 / tot_count
        new_count = tot_count

        state = NormalizeVecObsEnvState(
            mean=new_mean,
            var=new_var,
            count=new_count,
            env_state=state.env_state,
        )

        return (obs - state.mean) / jnp.sqrt(state.var + 1e-8), state

    def step(self, key, state, action, params=None):
        obs, env_state, reward, done, info = self._env.step(
            key, state.env_state, action, params
        )

        batch_mean = jnp.mean(obs, axis=0)
        batch_var = jnp.var(obs, axis=0)
        batch_count = obs.shape[0]

        delta = batch_mean - state.mean
        tot_count = state.count + batch_count

        new_mean = state.mean + delta * batch_count / tot_count
        m_a = state.var * state.count
        m_b = batch_var * batch_count
        M2 = m_a + m_b + jnp.square(delta) * state.count * batch_count / tot_count
        new_var = M2 / tot_count
        new_count = tot_count

        state = NormalizeVecObsEnvState(
            mean=new_mean,
            var=new_var,
            count=new_count,
            env_state=env_state,
        )
        return (
            (obs - state.mean) / jnp.sqrt(state.var + 1e-8),
            state,
            reward,
            done,
            info,
        )


@struct.dataclass
class NormalizeVecRewEnvState:
    mean: jnp.ndarray
    var: jnp.ndarray
    count: float
    return_val: float
    env_state: environment.EnvState


class NormalizeVecReward(GymnaxWrapper):
    def __init__(self, env, gamma):
        super().__init__(env)
        self.gamma = gamma

    def reset(self, key, params=None):
        obs, state = self._env.reset(key, params)
        batch_count = obs.shape[0]
        state = NormalizeVecRewEnvState(
            mean=0.0,
            var=1.0,
            count=1e-4,
            return_val=jnp.zeros((batch_count,)),
            env_state=state,
        )
        return obs, state

    def step(self, key, state, action, params=None):
        obs, env_state, reward, done, info = self._env.step(
            key, state.env_state, action, params
        )
        return_val = state.return_val * self.gamma * (1 - done) + reward

        batch_mean = jnp.mean(return_val, axis=0)
        batch_var = jnp.var(return_val, axis=0)
        batch_count = obs.shape[0]

        delta = batch_mean - state.mean
        tot_count = state.count + batch_count

        new_mean = state.mean + delta * batch_count / tot_count
        m_a = state.var * state.count
        m_b = batch_var * batch_count
        M2 = m_a + m_b + jnp.square(delta) * state.count * batch_count / tot_count
        new_var = M2 / tot_count
        new_count = tot_count

        state = NormalizeVecRewEnvState(
            mean=new_mean,
            var=new_var,
            count=new_count,
            return_val=return_val,
            env_state=env_state,
        )
        return obs, state, reward / jnp.sqrt(state.var + 1e-8), done, info

# %%
import jax
import jax.numpy as jnp
import flax.linen as nn
import numpy as np
import optax
from flax.linen.initializers import constant, orthogonal
from typing import Sequence, NamedTuple, Any
from flax.training.train_state import TrainState
import distrax

class ActorCritic(nn.Module):
    action_dim: Sequence[int]
    activation: str = "tanh"

    @nn.compact
    def __call__(self, x):
        if self.activation == "relu":
            activation = nn.relu
        else:
            activation = nn.tanh
        actor_mean = nn.Dense(
            256, kernel_init=orthogonal(np.sqrt(2)), bias_init=constant(0.0)
        )(x)
        actor_mean = activation(actor_mean)
        actor_mean = nn.Dense(
            256, kernel_init=orthogonal(np.sqrt(2)), bias_init=constant(0.0)
        )(actor_mean)
        actor_mean = activation(actor_mean)
        actor_mean = nn.Dense(
            self.action_dim, kernel_init=orthogonal(0.01), bias_init=constant(0.0)
        )(actor_mean)
        actor_logtstd = self.param("log_std", nn.initializers.zeros, (self.action_dim,))
        pi = distrax.MultivariateNormalDiag(actor_mean, jnp.exp(actor_logtstd))

        critic = nn.Dense(
            256, kernel_init=orthogonal(np.sqrt(2)), bias_init=constant(0.0)
        )(x)
        critic = activation(critic)
        critic = nn.Dense(
            256, kernel_init=orthogonal(np.sqrt(2)), bias_init=constant(0.0)
        )(critic)
        critic = activation(critic)
        critic = nn.Dense(1, kernel_init=orthogonal(1.0), bias_init=constant(0.0))(
            critic
        )

        return pi, jnp.squeeze(critic, axis=-1)


class Transition(NamedTuple):
    done: jnp.ndarray
    action: jnp.ndarray
    value: jnp.ndarray
    reward: jnp.ndarray
    log_prob: jnp.ndarray
    obs: jnp.ndarray
    info: jnp.ndarray


def make_train(config):
    config["NUM_UPDATES"] = (
        config["TOTAL_TIMESTEPS"] // config["NUM_STEPS"] // config["NUM_ENVS"]
    )
    config["MINIBATCH_SIZE"] = (
        config["NUM_ENVS"] * config["NUM_STEPS"] // config["NUM_MINIBATCHES"]
    )
    print(config["MINIBATCH_SIZE"])
    env, env_params = BraxGymnaxWrapper(config["ENV_NAME"]), None
    env = LogWrapper(env)
    env = ClipAction(env)
    env = VecEnv(env)
    if config["NORMALIZE_ENV"]:
        env = NormalizeVecObservation(env)
        env = NormalizeVecReward(env, config["GAMMA"])

    def linear_schedule(count):
        frac = (
            1.0
            - (count // (config["NUM_MINIBATCHES"] * config["UPDATE_EPOCHS"]))
            / config["NUM_UPDATES"]
        )
        return config["LR"] * frac

    def train(rng):
        # INIT NETWORK
        network = ActorCritic(
            env.action_space(env_params).shape[0], activation=config["ACTIVATION"]
        )
        rng, _rng = jax.random.split(rng)
        init_x = jnp.zeros(env.observation_space(env_params).shape)
        network_params = network.init(_rng, init_x)
        if config["ANNEAL_LR"]:
            tx = optax.chain(
                optax.clip_by_global_norm(config["MAX_GRAD_NORM"]),
                optax.adam(learning_rate=linear_schedule, eps=1e-5),
            )
        else:
            tx = optax.chain(
                optax.clip_by_global_norm(config["MAX_GRAD_NORM"]),
                optax.adam(config["LR"], eps=1e-5),
            )
        train_state = TrainState.create(
            apply_fn=network.apply,
            params=network_params,
            tx=tx,
        )

        # INIT ENV
        rng, _rng = jax.random.split(rng)
        reset_rng = jax.random.split(_rng, config["NUM_ENVS"])
        obsv, env_state = env.reset(reset_rng, env_params)

        # TRAIN LOOP
        def _update_step(runner_state, unused):
            # COLLECT TRAJECTORIES
            def _env_step(runner_state, unused):
                train_state, env_state, last_obs, rng = runner_state

                # SELECT ACTION
                rng, _rng = jax.random.split(rng)
                pi, value = network.apply(train_state.params, last_obs)
                action = pi.sample(seed=_rng)
                log_prob = pi.log_prob(action)

                # STEP ENV
                rng, _rng = jax.random.split(rng)
                rng_step = jax.random.split(_rng, config["NUM_ENVS"])
                obsv, env_state, reward, done, info = env.step(
                    rng_step, env_state, action, env_params
                )
                transition = Transition(
                    done, action, value, reward, log_prob, last_obs, info
                )
                runner_state = (train_state, env_state, obsv, rng)
                return runner_state, transition

            runner_state, traj_batch = jax.lax.scan(
                _env_step, runner_state, None, config["NUM_STEPS"]
            )

            # CALCULATE ADVANTAGE
            train_state, env_state, last_obs, rng = runner_state
            _, last_val = network.apply(train_state.params, last_obs)

            def _calculate_gae(traj_batch, last_val):
                def _get_advantages(gae_and_next_value, transition):
                    gae, next_value = gae_and_next_value
                    done, value, reward = (
                        transition.done,
                        transition.value,
                        transition.reward,
                    )
                    delta = reward + config["GAMMA"] * next_value * (1 - done) - value
                    gae = (
                        delta
                        + config["GAMMA"] * config["GAE_LAMBDA"] * (1 - done) * gae
                    )
                    return (gae, value), gae

                _, advantages = jax.lax.scan(
                    _get_advantages,
                    (jnp.zeros_like(last_val), last_val),
                    traj_batch,
                    reverse=True,
                    unroll=16,
                )
                return advantages, advantages + traj_batch.value

            advantages, targets = _calculate_gae(traj_batch, last_val)

            # UPDATE NETWORK
            def _update_epoch(update_state, unused):
                def _update_minbatch(train_state, batch_info):
                    traj_batch, advantages, targets = batch_info

                    def _loss_fn(params, traj_batch, gae, targets):
                        # RERUN NETWORK
                        pi, value = network.apply(params, traj_batch.obs)
                        log_prob = pi.log_prob(traj_batch.action)

                        # CALCULATE VALUE LOSS
                        value_pred_clipped = traj_batch.value + (
                            value - traj_batch.value
                        ).clip(-config["CLIP_EPS"], config["CLIP_EPS"])
                        value_losses = jnp.square(value - targets)
                        value_losses_clipped = jnp.square(value_pred_clipped - targets)
                        value_loss = (
                            0.5 * jnp.maximum(value_losses, value_losses_clipped).mean()
                        )

                        # CALCULATE ACTOR LOSS
                        ratio = jnp.exp(log_prob - traj_batch.log_prob)
                        gae = (gae - gae.mean()) / (gae.std() + 1e-8)
                        loss_actor1 = ratio * gae
                        loss_actor2 = (
                            jnp.clip(
                                ratio,
                                1.0 - config["CLIP_EPS"],
                                1.0 + config["CLIP_EPS"],
                            )
                            * gae
                        )
                        loss_actor = -jnp.minimum(loss_actor1, loss_actor2)
                        loss_actor = loss_actor.mean()
                        entropy = pi.entropy().mean()

                        total_loss = (
                            loss_actor
                            + config["VF_COEF"] * value_loss
                            - config["ENT_COEF"] * entropy
                        )
                        return total_loss, (value_loss, loss_actor, entropy)

                    grad_fn = jax.value_and_grad(_loss_fn, has_aux=True)
                    total_loss, grads = grad_fn(
                        train_state.params, traj_batch, advantages, targets
                    )
                    train_state = train_state.apply_gradients(grads=grads)
                    return train_state, total_loss

                train_state, traj_batch, advantages, targets, rng = update_state
                rng, _rng = jax.random.split(rng)
                batch_size = config["MINIBATCH_SIZE"] * config["NUM_MINIBATCHES"]
                assert (
                    batch_size == config["NUM_STEPS"] * config["NUM_ENVS"]
                ), "batch size must be equal to number of steps * number of envs"
                permutation = jax.random.permutation(_rng, batch_size)
                batch = (traj_batch, advantages, targets)
                batch = jax.tree_util.tree_map(
                    lambda x: x.reshape((batch_size,) + x.shape[2:]), batch
                )
                shuffled_batch = jax.tree_util.tree_map(
                    lambda x: jnp.take(x, permutation, axis=0), batch
                )
                minibatches = jax.tree_util.tree_map(
                    lambda x: jnp.reshape(
                        x, [config["NUM_MINIBATCHES"], -1] + list(x.shape[1:])
                    ),
                    shuffled_batch,
                )
                train_state, total_loss = jax.lax.scan(
                    _update_minbatch, train_state, minibatches
                )
                update_state = (train_state, traj_batch, advantages, targets, rng)
                return update_state, total_loss

            update_state = (train_state, traj_batch, advantages, targets, rng)
            update_state, loss_info = jax.lax.scan(
                _update_epoch, update_state, None, config["UPDATE_EPOCHS"]
            )
            train_state = update_state[0]
            metric = traj_batch.info
            rng = update_state[-1]
            if config.get("DEBUG"):

                def callback(info):
                    return_values = info["returned_episode_returns"][
                        info["returned_episode"]
                    ]
                    timesteps = (
                        info["timestep"][info["returned_episode"]] * config["NUM_ENVS"]
                    )
                    for t in range(len(timesteps)):
                        print(
                            f"global step={timesteps[t]}, episodic return={return_values[t]}"
                        )

                jax.debug.callback(callback, metric)

            runner_state = (train_state, env_state, last_obs, rng)
            return runner_state, metric

        rng, _rng = jax.random.split(rng)
        runner_state = (train_state, env_state, obsv, _rng)
        print(config["NUM_UPDATES"])
        runner_state, metric = jax.lax.scan(
            _update_step, runner_state, None, config["NUM_UPDATES"]
        )
        return {"runner_state": runner_state, "metrics": metric}

    return train

# %%
if __name__ == "__main__":
    config = {
        "LR": 3e-4,
        "NUM_ENVS": 2048,
        "NUM_STEPS": 10,
        "TOTAL_TIMESTEPS": 105e7,
        "UPDATE_EPOCHS": 4,
        "NUM_MINIBATCHES": 32,
        "GAMMA": 0.99,
        "GAE_LAMBDA": 0.95,
        "CLIP_EPS": 0.2,
        "ENT_COEF": 0.0,
        "VF_COEF": 0.5,
        "MAX_GRAD_NORM": 0.5,
        "ACTIVATION": "tanh",
        "ENV_NAME": "ant",
        "ANNEAL_LR": False,
        "NORMALIZE_ENV": True,
        "DEBUG": True,
    }
    rng = jax.random.PRNGKey(3)
    train_jit = jax.jit(make_train(config))
    out = train_jit(rng)
# Out:
# 640
# 2441.0
# global step=20480, episodic return=11.554651260375977
# global step=22528, episodic return=12.745279312133789
# global step=22528, episodic return=13.953179359436035
# global step=24576, episodic return=16.12594223022461
# global step=24576, episodic return=14.925283432006836
# global step=24576, episodic return=13.349305152893066
# global step=24576, episodic return=14.336023330688477
# global step=24576, episodic return=13.157261848449707
# global step=26624, episodic return=14.714787483215332
# global step=26624, episodic return=16.709346771240234
# global step=26624, episodic return=15.247873306274414
# global step=26624, episodic return=15.474729537963867
# global step=26624, episodic return=17.274738311767578
# global step=26624, episodic return=10.353468894958496
# global step=26624, episodic return=13.410882949829102
# global step=26624, episodic return=13.662683486938477
# global step=26624, episodic return=12.016700744628906
# global step=28672, episodic return=12.314329147338867
# global step=28672, episodic return=15.827260971069336
# global step=28672, episodic return=20.729734420776367
# global step=28672, episodic return=17.632675170898438
# global step=28672, episodic return=9.694689750671387
# global step=28672, episodic return=16.923080444335938
# global step=28672, episodic return=17.59232521057129
# global step=28672, episodic return=17.162555694580078
# global step=30720, episodic return=18.461822509765625
# global step=30720, episodic return=18.692302703857422
# global step=30720, episodic return=15.114995002746582
# global step=30720, episodic return=19.64983558654785
# global step=30720, episodic return=19.484127044677734
# global step=30720, episodic return=19.62419319152832
# global step=30720, episodic return=13.562053680419922
# global step=30720, episodic return=16.912322998046875
# global step=30720, episodic return=18.154909133911133
# global step=30720, episodic return=17.132043838500977
# global step=30720, episodic return=22.03915023803711
# global step=32768, episodic return=13.225275993347168
# global step=32768, episodic return=16.31988525390625
# global step=32768, episodic return=11.5420503616333
# global step=32768, episodic return=20.21349334716797
# global step=32768, episodic return=16.773571014404297
# global step=32768, episodic return=16.431964874267578
# global step=32768, episodic return=22.24080467224121
# global step=34816, episodic return=20.49828338623047
# global step=34816, episodic return=21.720882415771484
# global step=34816, episodic return=15.60880184173584
# global step=34816, episodic return=17.719863891601562
# global step=34816, episodic return=13.486001968383789
# global step=34816, episodic return=15.889033317565918
# global step=34816, episodic return=17.024837493896484
# global step=34816, episodic return=24.90572738647461
# global step=34816, episodic return=22.929157257080078
# global step=34816, episodic return=28.396284103393555
# global step=34816, episodic return=10.550920486450195
# global step=34816, episodic return=16.039194107055664
# global step=34816, episodic return=14.40113639831543
# global step=34816, episodic return=20.389665603637695
# global step=34816, episodic return=24.992630004882812
# global step=34816, episodic return=17.17799949645996
# global step=36864, episodic return=18.652494430541992
# global step=36864, episodic return=18.51028823852539
# global step=36864, episodic return=19.81229019165039
# global step=36864, episodic return=27.165494918823242
# global step=36864, episodic return=16.8690128326416
# global step=36864, episodic return=26.49761390686035
# global step=36864, episodic return=20.96388053894043
# global step=36864, episodic return=18.949621200561523
# global step=36864, episodic return=21.32973289489746
# global step=36864, episodic return=12.602554321289062
# global step=36864, episodic return=22.530838012695312
# global step=36864, episodic return=18.813507080078125
# global step=36864, episodic return=18.109895706176758
# global step=36864, episodic return=22.16301727294922
# global step=36864, episodic return=14.866338729858398
# global step=36864, episodic return=20.312379837036133
# global step=36864, episodic return=19.37312126159668
# global step=36864, episodic return=13.770611763000488
# global step=36864, episodic return=16.125905990600586
# global step=36864, episodic return=21.49144744873047
# global step=36864, episodic return=18.454017639160156
# global step=36864, episodic return=17.565736770629883
# global step=36864, episodic return=13.473660469055176
# global step=38912, episodic return=32.54963684082031
# global step=38912, episodic return=16.761249542236328
# global step=38912, episodic return=15.089305877685547
# global step=38912, episodic return=25.200061798095703
# global step=38912, episodic return=15.453253746032715
# global step=38912, episodic return=15.974076271057129
# global step=38912, episodic return=19.17725372314453
# global step=38912, episodic return=18.10323715209961
# global step=38912, episodic return=20.784345626831055
# global step=38912, episodic return=19.231014251708984
# global step=38912, episodic return=20.303359985351562
# global step=38912, episodic return=18.175811767578125
# global step=38912, episodic return=25.744321823120117
# global step=38912, episodic return=20.602190017700195
# global step=38912, episodic return=16.390287399291992
# global step=38912, episodic return=22.722932815551758
# global step=38912, episodic return=30.28873062133789
# global step=38912, episodic return=23.41970443725586
# global step=40960, episodic return=17.844619750976562
# global step=40960, episodic return=20.954971313476562
# global step=40960, episodic return=14.423551559448242
# global step=40960, episodic return=15.34221076965332
# global step=40960, episodic return=20.710630416870117
# global step=40960, episodic return=16.59673309326172
# global step=40960, episodic return=32.099117279052734
# global step=40960, episodic return=19.475238800048828
# global step=40960, episodic return=21.596446990966797
# global step=40960, episodic return=18.273990631103516
# global step=40960, episodic return=22.40684700012207
# global step=40960, episodic return=26.94872283935547
# global step=40960, episodic return=17.641794204711914
# global step=40960, episodic return=17.565858840942383
# global step=40960, episodic return=30.504802703857422
# global step=40960, episodic return=19.03843879699707
# global step=40960, episodic return=19.120880126953125
# global step=40960, episodic return=22.417314529418945
# global step=40960, episodic return=14.357297897338867
# global step=40960, episodic return=24.331512451171875
# global step=40960, episodic return=21.34109115600586
# global step=40960, episodic return=27.50461196899414
# global step=40960, episodic return=20.818021774291992
# global step=43008, episodic return=19.91598129272461
# global step=43008, episodic return=23.098522186279297
# global step=43008, episodic return=25.838924407958984
# global step=43008, episodic return=22.382431030273438
# global step=43008, episodic return=12.323330879211426
# global step=43008, episodic return=20.620622634887695
# global step=43008, episodic return=32.91651153564453
# global step=43008, episodic return=27.927539825439453
# global step=43008, episodic return=22.97743034362793
# global step=43008, episodic return=14.327911376953125
# global step=43008, episodic return=23.877079010009766
# global step=43008, episodic return=24.61617660522461
# global step=43008, episodic return=23.56371307373047
# global step=43008, episodic return=11.57244873046875
# global step=43008, episodic return=25.119874954223633
# global step=43008, episodic return=16.97978973388672
# global step=43008, episodic return=23.466995239257812
# global step=43008, episodic return=22.61505699157715
# global step=43008, episodic return=24.727216720581055
# global step=43008, episodic return=17.78782081604004
# global step=43008, episodic return=25.781150817871094
# global step=43008, episodic return=35.322391510009766
# global step=43008, episodic return=22.63779640197754
# global step=43008, episodic return=30.012353897094727
# global step=45056, episodic return=17.14520835876465
# global step=45056, episodic return=26.20213508605957
# global step=45056, episodic return=24.95090103149414
# global step=45056, episodic return=24.17472267150879
# global step=45056, episodic return=18.689224243164062
# global step=45056, episodic return=34.18684005737305
# global step=45056, episodic return=18.603267669677734
# global step=45056, episodic return=31.673912048339844
# global step=45056, episodic return=35.41725540161133
# global step=45056, episodic return=21.78520393371582
# global step=45056, episodic return=15.258071899414062
# global step=45056, episodic return=19.181772232055664
# global step=45056, episodic return=21.120874404907227
# global step=45056, episodic return=21.51141929626465
# global step=45056, episodic return=29.56959342956543
# global step=45056, episodic return=23.95893669128418
# global step=45056, episodic return=13.140863418579102
# global step=47104, episodic return=38.75672149658203
# global step=47104, episodic return=28.568687438964844
# global step=47104, episodic return=29.668212890625
# global step=47104, episodic return=29.689855575561523
# global step=47104, episodic return=24.297163009643555
# global step=47104, episodic return=15.427236557006836
# global step=47104, episodic return=29.415124893188477
# global step=47104, episodic return=19.821470260620117
# global step=47104, episodic return=23.950916290283203
# global step=47104, episodic return=17.768878936767578
# global step=47104, episodic return=23.25585174560547
# global step=47104, episodic return=22.403980255126953
# global step=47104, episodic return=25.00455093383789
# global step=47104, episodic return=23.6005916595459
# global step=47104, episodic return=12.24441146850586
# global step=47104, episodic return=23.8610782623291
# global step=49152, episodic return=19.728588104248047
# global step=49152, episodic return=23.071128845214844
# global step=49152, episodic return=25.80487823486328
# global step=49152, episodic return=22.315574645996094
# global step=49152, episodic return=26.07501220703125
# global step=49152, episodic return=20.180830001831055
# global step=49152, episodic return=34.31247329711914
# global step=49152, episodic return=20.03620719909668
# global step=49152, episodic return=31.760009765625
# global step=49152, episodic return=21.983768463134766
# global step=49152, episodic return=23.463581085205078
# global step=49152, episodic return=23.338891983032227
# global step=49152, episodic return=14.359352111816406
# global step=49152, episodic return=24.69293212890625
# global step=49152, episodic return=17.066844940185547
# global step=49152, episodic return=27.732421875
# global step=49152, episodic return=27.22307586669922
# global step=51200, episodic return=29.5067195892334
# global step=51200, episodic return=24.51018714904785
# global step=51200, episodic return=30.25736427307129
# global step=51200, episodic return=25.558744430541992
# global step=51200, episodic return=23.821611404418945
# global step=51200, episodic return=24.583892822265625
# global step=51200, episodic return=20.593477249145508
# global step=51200, episodic return=18.017580032348633
# global step=51200, episodic return=22.610469818115234
# global step=51200, episodic return=31.61149024963379
# global step=51200, episodic return=33.929752349853516
# global step=51200, episodic return=11.605131149291992
# global step=51200, episodic return=28.706531524658203
# global step=51200, episodic return=36.087181091308594
# global step=51200, episodic return=30.454530715942383
# global step=51200, episodic return=16.14313507080078
# global step=51200, episodic return=23.430545806884766
# global step=51200, episodic return=29.539005279541016
# global step=51200, episodic return=27.821020126342773
# global step=51200, episodic return=25.292741775512695
# global step=51200, episodic return=22.968151092529297
# global step=51200, episodic return=19.88810920715332
# global step=51200, episodic return=27.152721405029297
# global step=51200, episodic return=20.733436584472656
# global step=51200, episodic return=35.60017776489258
# global step=53248, episodic return=39.8956413269043
# global step=53248, episodic return=22.747920989990234
# global step=53248, episodic return=28.449542999267578
# global step=53248, episodic return=27.988019943237305
# global step=53248, episodic return=26.224822998046875
# global step=53248, episodic return=26.802318572998047
# global step=53248, episodic return=35.80650329589844
# global step=53248, episodic return=20.875720977783203
# global step=53248, episodic return=33.289852142333984
# global step=53248, episodic return=27.394346237182617
# global step=53248, episodic return=28.37220573425293
# global step=53248, episodic return=23.32646942138672
# global step=53248, episodic return=24.477842330932617
# global step=53248, episodic return=28.31981658935547
# global step=53248, episodic return=27.92949104309082
# global step=53248, episodic return=35.39274597167969
# global step=53248, episodic return=22.954547882080078
# global step=55296, episodic return=26.369586944580078
# global step=55296, episodic return=15.511127471923828
# global step=55296, episodic return=39.403770446777344
# global step=55296, episodic return=24.0579891204834
# global step=55296, episodic return=16.995901107788086
# global step=55296, episodic return=26.62527847290039
# global step=55296, episodic return=39.584136962890625
# global step=55296, episodic return=41.841827392578125
# global step=55296, episodic return=44.445396423339844
# global step=55296, episodic return=30.896730422973633
# global step=55296, episodic return=28.286731719970703
# global step=55296, episodic return=22.38971519470215
# global step=55296, episodic return=26.183612823486328
# global step=55296, episodic return=22.266550064086914
# global step=55296, episodic return=32.72359085083008
# global step=55296, episodic return=20.879064559936523
# global step=55296, episodic return=30.163482666015625
# global step=55296, episodic return=43.074092864990234
# global step=55296, episodic return=26.88327407836914
# global step=55296, episodic return=42.428794860839844
# global step=55296, episodic return=23.75693130493164
# global step=57344, episodic return=24.233829498291016
# global step=57344, episodic return=18.520549774169922
# global step=57344, episodic return=43.87704849243164
# global step=57344, episodic return=26.550800323486328
# global step=57344, episodic return=22.940725326538086
# global step=57344, episodic return=29.79697036743164
# global step=57344, episodic return=20.789142608642578
# global step=57344, episodic return=20.981910705566406
# global step=57344, episodic return=26.996047973632812
# global step=57344, episodic return=30.560768127441406
# global step=57344, episodic return=27.173507690429688
# global step=57344, episodic return=34.79344940185547
# global step=57344, episodic return=22.511825561523438
# global step=57344, episodic return=17.9902286529541
# global step=57344, episodic return=31.41013526916504
# global step=57344, episodic return=25.435813903808594
# global step=57344, episodic return=25.81626319885254
# global step=57344, episodic return=28.495878219604492
# global step=57344, episodic return=21.041324615478516
# global step=59392, episodic return=40.796714782714844
# global step=59392, episodic return=33.939456939697266
# global step=59392, episodic return=29.514183044433594
# global step=59392, episodic return=39.823604583740234
# global step=59392, episodic return=28.788835525512695
# global step=59392, episodic return=35.77912521362305
# global step=59392, episodic return=17.430633544921875
# global step=59392, episodic return=37.750038146972656
# global step=59392, episodic return=21.04129981994629
# global step=59392, episodic return=32.69691467285156
# global step=59392, episodic return=28.62200927734375
# global step=59392, episodic return=16.37636947631836
# global step=59392, episodic return=35.61224365234375
# global step=59392, episodic return=31.82200813293457
# global step=59392, episodic return=44.57863235473633
# global step=59392, episodic return=25.909971237182617
# global step=59392, episodic return=25.076711654663086
# global step=59392, episodic return=24.5968074798584
# global step=59392, episodic return=36.125606536865234
# global step=59392, episodic return=30.508007049560547
# global step=59392, episodic return=33.1527214050293
# global step=61440, episodic return=24.760046005249023
# global step=61440, episodic return=26.658906936645508
# global step=61440, episodic return=26.35900115966797
# global step=61440, episodic return=31.856605529785156
# global step=61440, episodic return=25.479467391967773
# global step=61440, episodic return=38.76963424682617
# global step=61440, episodic return=48.33589172363281
# global step=61440, episodic return=24.964187622070312
# global step=61440, episodic return=23.635730743408203
# global step=61440, episodic return=25.61429786682129
# global step=61440, episodic return=19.296642303466797
# global step=61440, episodic return=23.079803466796875
# global step=61440, episodic return=29.994909286499023
# global step=61440, episodic return=41.09090805053711
# global step=61440, episodic return=22.515607833862305
# global step=61440, episodic return=29.85024070739746
# global step=61440, episodic return=21.59541130065918
# global step=61440, episodic return=24.977571487426758
# global step=61440, episodic return=45.426666259765625
# global step=61440, episodic return=23.520263671875
# global step=61440, episodic return=27.22663688659668
# global step=61440, episodic return=38.03569412231445
# global step=61440, episodic return=21.05771827697754
# global step=61440, episodic return=39.29927444458008
# global step=61440, episodic return=21.812429428100586
# global step=61440, episodic return=20.572505950927734
# global step=61440, episodic return=29.593521118164062
# global step=61440, episodic return=33.644073486328125
# global step=61440, episodic return=39.897186279296875
# global step=61440, episodic return=21.143884658813477
# global step=61440, episodic return=25.786773681640625
# global step=61440, episodic return=32.201473236083984
# global step=63488, episodic return=29.548864364624023
# global step=63488, episodic return=30.34920310974121
# global step=63488, episodic return=47.44487762451172
# global step=63488, episodic return=29.241127014160156
# global step=63488, episodic return=41.96184158325195
# global step=63488, episodic return=28.223379135131836
# global step=63488, episodic return=23.697275161743164
# global step=63488, episodic return=26.10470199584961
# global step=63488, episodic return=35.194419860839844
# global step=63488, episodic return=23.956689834594727
# global step=63488, episodic return=37.88330078125
# global step=63488, episodic return=25.60475730895996
# global step=63488, episodic return=45.08750915527344
# global step=63488, episodic return=30.778980255126953
# global step=65536, episodic return=29.266489028930664
# global step=65536, episodic return=26.498952865600586
# global step=65536, episodic return=48.026859283447266
# global step=65536, episodic return=22.93172264099121
# global step=65536, episodic return=29.002683639526367
# global step=65536, episodic return=25.966386795043945
# global step=65536, episodic return=37.541046142578125
# global step=65536, episodic return=23.850038528442383
# global step=65536, episodic return=22.008657455444336
# global step=65536, episodic return=31.03042984008789
# global step=65536, episodic return=42.36947250366211
# global step=65536, episodic return=40.88726806640625
# global step=65536, episodic return=32.36115646362305
# global step=65536, episodic return=32.9295654296875
# global step=67584, episodic return=25.841527938842773
# global step=67584, episodic return=37.961944580078125
# global step=67584, episodic return=31.626495361328125
# global step=67584, episodic return=29.370603561401367
# global step=67584, episodic return=53.138450622558594
# global step=67584, episodic return=36.34986877441406
# global step=67584, episodic return=39.89232635498047
# global step=67584, episodic return=24.456417083740234
# global step=67584, episodic return=30.053531646728516
# global step=67584, episodic return=27.216617584228516
# global step=67584, episodic return=50.537723541259766
# global step=67584, episodic return=29.790122985839844
# global step=67584, episodic return=22.286479949951172
# global step=67584, episodic return=16.67276954650879
# global step=69632, episodic return=31.59249496459961
# global step=69632, episodic return=30.361173629760742
# global step=69632, episodic return=40.97942352294922
# global step=69632, episodic return=46.00498962402344
# global step=69632, episodic return=40.3205451965332
# global step=69632, episodic return=24.785385131835938
# global step=71680, episodic return=26.743886947631836
# global step=71680, episodic return=32.14136505126953
# global step=71680, episodic return=45.425315856933594
# global step=71680, episodic return=48.327545166015625
# global step=71680, episodic return=31.694950103759766
# global step=71680, episodic return=29.675949096679688
# global step=71680, episodic return=39.66630554199219
# global step=71680, episodic return=31.654630661010742
# global step=71680, episodic return=12.656196594238281
# global step=71680, episodic return=47.551509857177734
# global step=73728, episodic return=31.899507522583008
# global step=73728, episodic return=56.776920318603516
# global step=73728, episodic return=26.418254852294922
# global step=73728, episodic return=44.06592559814453
# global step=73728, episodic return=30.327777862548828
# global step=73728, episodic return=30.202917098999023
# global step=73728, episodic return=48.88438415527344
# global step=75776, episodic return=25.93385124206543
# global step=75776, episodic return=31.149093627929688
# global step=75776, episodic return=50.676307678222656
# global step=75776, episodic return=42.92131805419922
# global step=75776, episodic return=36.752418518066406
# global step=75776, episodic return=44.13315963745117
# global step=75776, episodic return=50.12105178833008
# global step=75776, episodic return=44.9609375
# global step=75776, episodic return=31.487178802490234
# global step=75776, episodic return=36.2437858581543
# global step=75776, episodic return=20.13117790222168
# global step=75776, episodic return=29.78560447692871
# global step=75776, episodic return=40.11833572387695
# global step=75776, episodic return=50.32684326171875
# global step=77824, episodic return=28.586071014404297
# global step=77824, episodic return=22.878643035888672
# global step=77824, episodic return=28.720651626586914
# global step=77824, episodic return=25.770893096923828
# global step=77824, episodic return=29.747459411621094
# global step=77824, episodic return=29.702587127685547
# global step=77824, episodic return=33.30670166015625
# global step=77824, episodic return=36.925350189208984
# global step=77824, episodic return=22.080228805541992
# global step=79872, episodic return=34.03180694580078
# global step=79872, episodic return=29.23375129699707
# global step=79872, episodic return=32.79082107543945
# global step=79872, episodic return=30.454771041870117
# global step=79872, episodic return=57.22694778442383
# global step=79872, episodic return=14.975834846496582
# global step=79872, episodic return=27.14026641845703
# global step=79872, episodic return=32.480560302734375
# global step=79872, episodic return=50.99970245361328
# global step=79872, episodic return=41.091060638427734
# global step=79872, episodic return=36.337135314941406
# global step=79872, episodic return=46.02817916870117
# global step=79872, episodic return=22.104045867919922
# global step=81920, episodic return=48.199092864990234
# global step=81920, episodic return=43.290225982666016
# global step=81920, episodic return=20.380460739135742
# global step=81920, episodic return=57.65658187866211
# global step=81920, episodic return=40.73664093017578
# global step=83968, episodic return=31.644947052001953
# global step=83968, episodic return=39.9110221862793
# global step=83968, episodic return=51.156585693359375
# global step=83968, episodic return=32.573402404785156
# global step=83968, episodic return=33.17317581176758
# global step=83968, episodic return=58.63353729248047
# global step=83968, episodic return=28.386613845825195
# global step=83968, episodic return=46.53446960449219
# global step=83968, episodic return=26.368261337280273
# global step=83968, episodic return=31.375091552734375
# global step=83968, episodic return=57.69037628173828
# global step=83968, episodic return=40.147377014160156
# global step=86016, episodic return=34.99257278442383
# global step=86016, episodic return=48.5970344543457
# global step=86016, episodic return=39.69050598144531
# global step=86016, episodic return=58.68571853637695
# global step=86016, episodic return=51.80527877807617
# global step=86016, episodic return=54.532684326171875
# global step=86016, episodic return=47.828094482421875
# global step=86016, episodic return=34.54133605957031
# global step=88064, episodic return=46.06497573852539
# global step=88064, episodic return=49.90958786010742
# global step=88064, episodic return=44.96302795410156
# global step=88064, episodic return=38.40050506591797
# global step=90112, episodic return=44.15735626220703
# global step=90112, episodic return=58.03539276123047
# global step=90112, episodic return=48.602272033691406
# global step=90112, episodic return=41.26414108276367
# global step=92160, episodic return=48.83836364746094
# global step=94208, episodic return=44.50038528442383
# global step=94208, episodic return=46.27854919433594
# global step=94208, episodic return=66.6900863647461
# global step=94208, episodic return=67.76415252685547
# global step=94208, episodic return=42.81299591064453
# global step=96256, episodic return=39.783084869384766
# global step=96256, episodic return=32.83729934692383
# global step=96256, episodic return=46.94782257080078
# global step=96256, episodic return=28.812381744384766
# global step=98304, episodic return=41.647117614746094
# global step=98304, episodic return=53.720436096191406
# global step=98304, episodic return=36.66777038574219
# global step=98304, episodic return=52.445335388183594
# global step=100352, episodic return=26.63527488708496
# global step=100352, episodic return=59.100242614746094
# global step=102400, episodic return=43.98141098022461
# global step=102400, episodic return=50.02723693847656
# global step=102400, episodic return=40.22515869140625
# global step=102400, episodic return=38.92822265625
# global step=104448, episodic return=45.6509895324707
# global step=104448, episodic return=56.19510269165039
# global step=104448, episodic return=54.372291564941406
# global step=106496, episodic return=57.601600646972656
# global step=106496, episodic return=62.15068817138672
# global step=108544, episodic return=53.239688873291016
# global step=108544, episodic return=46.66474914550781
# global step=108544, episodic return=63.39588928222656
# global step=108544, episodic return=70.5770492553711
# global step=108544, episodic return=36.78515625
# global step=110592, episodic return=42.33374786376953
# global step=110592, episodic return=75.08546447753906
# global step=110592, episodic return=75.31702423095703
# global step=110592, episodic return=48.30303192138672
# global step=114688, episodic return=30.10585594177246
# global step=114688, episodic return=76.14234161376953
# global step=114688, episodic return=43.60008239746094
# global step=114688, episodic return=77.42498779296875
# global step=116736, episodic return=53.095115661621094
# global step=116736, episodic return=62.948726654052734
# global step=116736, episodic return=67.06539916992188
# global step=116736, episodic return=66.8061752319336
# global step=116736, episodic return=56.60683822631836
# global step=118784, episodic return=76.21183776855469
# global step=118784, episodic return=81.90857696533203
# global step=120832, episodic return=82.93011474609375
# global step=120832, episodic return=76.5168685913086
# global step=122880, episodic return=80.83229064941406
# global step=122880, episodic return=85.02930450439453
# global step=122880, episodic return=86.56298065185547
# global step=122880, episodic return=54.130062103271484
# global step=122880, episodic return=81.12874603271484
# global step=122880, episodic return=81.62818908691406
# global step=122880, episodic return=86.33744049072266
# global step=124928, episodic return=68.50324249267578
# global step=124928, episodic return=82.6859130859375
# global step=126976, episodic return=40.57444381713867
# global step=126976, episodic return=82.92739868164062
# global step=126976, episodic return=75.0104751586914
# global step=126976, episodic return=93.79899597167969
# global step=126976, episodic return=81.40438842773438
# global step=126976, episodic return=79.38481903076172
# global step=129024, episodic return=79.36113739013672
# global step=129024, episodic return=74.43040466308594
# global step=129024, episodic return=54.00556182861328
# global step=129024, episodic return=92.29244995117188
# global step=129024, episodic return=86.58837890625
# global step=131072, episodic return=90.50211334228516
# global step=131072, episodic return=94.21023559570312
# global step=133120, episodic return=81.74009704589844
# global step=133120, episodic return=94.03004455566406
# global step=133120, episodic return=82.95716857910156
# global step=133120, episodic return=92.3431625366211
# global step=133120, episodic return=87.60724639892578
# global step=133120, episodic return=96.62373352050781
# global step=133120, episodic return=93.69284057617188
# global step=135168, episodic return=92.8285903930664
# global step=135168, episodic return=79.66129302978516
# global step=135168, episodic return=85.20594787597656
# global step=135168, episodic return=88.0906753540039
# global step=137216, episodic return=89.94303131103516
# global step=137216, episodic return=92.32585906982422
# global step=137216, episodic return=95.11077880859375
# global step=137216, episodic return=88.38378143310547
# global step=137216, episodic return=95.68937683105469
# global step=137216, episodic return=95.03993225097656
# global step=137216, episodic return=88.53417205810547
# global step=139264, episodic return=94.9516372680664
# global step=139264, episodic return=56.375492095947266
# global step=141312, episodic return=96.22163391113281
# global step=141312, episodic return=99.7097396850586
# global step=141312, episodic return=58.000633239746094
# global step=141312, episodic return=97.47504425048828
# global step=141312, episodic return=94.71681213378906
# global step=141312, episodic return=82.69800567626953
# global step=141312, episodic return=91.67948913574219
# global step=143360, episodic return=90.25944519042969
# global step=143360, episodic return=97.46312713623047
# global step=143360, episodic return=105.82544708251953
# global step=145408, episodic return=87.93934631347656
# global step=145408, episodic return=92.01556396484375
# global step=145408, episodic return=84.12751007080078
# global step=145408, episodic return=105.90678405761719
# global step=145408, episodic return=92.9876480102539
# global step=145408, episodic return=92.0562973022461
# global step=147456, episodic return=100.4327163696289
# global step=147456, episodic return=102.8005599975586
# global step=147456, episodic return=96.4285888671875
# global step=147456, episodic return=87.09577178955078
# global step=147456, episodic return=94.3415756225586
# global step=147456, episodic return=68.20740509033203
# global step=147456, episodic return=90.71330261230469
# global step=147456, episodic return=71.72872924804688
# global step=147456, episodic return=97.43955993652344
# global step=147456, episodic return=100.4208984375
# global step=149504, episodic return=101.5416259765625
# global step=149504, episodic return=89.48754119873047
# global step=149504, episodic return=97.769287109375
# global step=149504, episodic return=92.54122924804688
# global step=149504, episodic return=91.39165496826172
# global step=149504, episodic return=102.14598083496094
# global step=149504, episodic return=102.92407989501953
# global step=149504, episodic return=96.98768615722656
# global step=151552, episodic return=99.3162612915039
# global step=151552, episodic return=93.02562713623047
# global step=151552, episodic return=106.38915252685547
# global step=151552, episodic return=92.19133758544922
# global step=151552, episodic return=103.97177124023438
# global step=151552, episodic return=84.26548767089844
# global step=151552, episodic return=104.96980285644531
# global step=151552, episodic return=103.96966552734375
# global step=151552, episodic return=86.40176391601562
# global step=151552, episodic return=95.57982635498047
# global step=151552, episodic return=87.3830795288086
# global step=151552, episodic return=103.4150161743164
# global step=151552, episodic return=79.52281951904297
# global step=151552, episodic return=102.2806396484375
# global step=153600, episodic return=97.945068359375
# global step=153600, episodic return=103.27804565429688
# global step=153600, episodic return=86.6665267944336
# global step=153600, episodic return=99.97144317626953
# global step=153600, episodic return=100.25025177001953
# global step=153600, episodic return=103.85826110839844
# global step=153600, episodic return=92.053955078125
# global step=153600, episodic return=74.82785034179688
# global step=153600, episodic return=106.03672790527344
# global step=153600, episodic return=97.72848510742188
# global step=153600, episodic return=102.82966613769531
# global step=153600, episodic return=93.78175354003906
# global step=155648, episodic return=69.15684509277344
# global step=155648, episodic return=101.51361083984375
# global step=155648, episodic return=92.96593475341797
# global step=155648, episodic return=99.09984588623047
# global step=155648, episodic return=106.25120544433594
# global step=155648, episodic return=110.2123031616211
# global step=155648, episodic return=102.48561096191406
# global step=155648, episodic return=81.433837890625
# global step=155648, episodic return=88.80509948730469
# global step=157696, episodic return=102.80564880371094
# global step=157696, episodic return=107.93008422851562
# global step=157696, episodic return=103.74533081054688
# global step=157696, episodic return=104.95759582519531
# global step=157696, episodic return=101.92753601074219
# global step=157696, episodic return=109.07699584960938
# global step=157696, episodic return=110.77674102783203
# global step=157696, episodic return=101.69591522216797
# global step=157696, episodic return=109.32894134521484
# global step=157696, episodic return=94.51333618164062
# global step=157696, episodic return=97.28564453125
# global step=159744, episodic return=94.68798828125
# global step=159744, episodic return=87.24068450927734
# global step=159744, episodic return=102.52113342285156
# global step=159744, episodic return=104.63984680175781
# global step=159744, episodic return=103.45599365234375
# global step=159744, episodic return=116.08088684082031
# global step=159744, episodic return=94.3818588256836
# global step=159744, episodic return=103.83818817138672
# global step=159744, episodic return=112.3884506225586
# global step=159744, episodic return=111.43128204345703
# global step=159744, episodic return=62.266807556152344
# global step=159744, episodic return=78.11959838867188
# global step=159744, episodic return=108.79505157470703
# global step=159744, episodic return=101.9054183959961
# global step=159744, episodic return=110.54951477050781
# global step=159744, episodic return=101.89928436279297
# global step=159744, episodic return=113.66471862792969
# global step=159744, episodic return=97.50342559814453
# global step=161792, episodic return=102.56208801269531
# global step=161792, episodic return=110.12513732910156
# global step=161792, episodic return=109.76177215576172
# global step=161792, episodic return=95.33382415771484
# global step=161792, episodic return=109.55280303955078
# global step=161792, episodic return=88.09577941894531
# global step=161792, episodic return=96.61662292480469
# global step=161792, episodic return=115.36493682861328
# global step=161792, episodic return=103.87212371826172
# global step=161792, episodic return=94.72981262207031
# global step=161792, episodic return=94.16889953613281
# global step=161792, episodic return=104.4385757446289
# global step=163840, episodic return=90.71070098876953
# global step=163840, episodic return=105.70320129394531
# global step=163840, episodic return=108.00370788574219
# global step=163840, episodic return=103.96102142333984
# global step=163840, episodic return=113.18975830078125
# global step=163840, episodic return=115.28062438964844
# global step=163840, episodic return=110.125
# global step=163840, episodic return=105.79325103759766
# global step=163840, episodic return=101.21333312988281
# global step=163840, episodic return=107.15278625488281
# global step=163840, episodic return=92.67709350585938
# global step=163840, episodic return=95.1716079711914
# global step=163840, episodic return=104.38285064697266
# global step=163840, episodic return=110.40129089355469
# global step=163840, episodic return=110.29425811767578
# global step=163840, episodic return=102.58930969238281
# global step=163840, episodic return=106.66421508789062
# global step=163840, episodic return=107.50814056396484
# global step=163840, episodic return=94.08892059326172
# global step=165888, episodic return=116.79576873779297
# global step=165888, episodic return=114.45430755615234
# global step=165888, episodic return=116.75948333740234
# global step=165888, episodic return=98.24073791503906
# global step=165888, episodic return=112.2802963256836
# global step=165888, episodic return=117.48340606689453
# global step=165888, episodic return=103.8323745727539
# global step=165888, episodic return=111.2095718383789
# global step=167936, episodic return=124.84639739990234
# global step=167936, episodic return=97.26417541503906
# global step=167936, episodic return=94.36869049072266
# global step=167936, episodic return=90.6471176147461
# global step=167936, episodic return=71.27446746826172
# global step=167936, episodic return=101.34735107421875
# global step=167936, episodic return=120.58533477783203
# global step=167936, episodic return=115.07866668701172
# global step=167936, episodic return=113.1708755493164
# global step=167936, episodic return=100.06767272949219
# global step=167936, episodic return=108.73670196533203
# global step=169984, episodic return=90.55636596679688
# global step=169984, episodic return=121.84024810791016
# global step=169984, episodic return=94.45930480957031
# global step=169984, episodic return=119.96272277832031
# global step=169984, episodic return=116.41924285888672
# global step=169984, episodic return=114.28514862060547
# global step=169984, episodic return=70.50210571289062
# global step=169984, episodic return=110.54472351074219
# global step=169984, episodic return=102.73931121826172
# global step=169984, episodic return=99.4014892578125
# global step=169984, episodic return=112.5964126586914
# global step=169984, episodic return=111.9673080444336
# global step=169984, episodic return=117.15524291992188
# global step=169984, episodic return=118.7060546875
# global step=169984, episodic return=114.94684600830078
# global step=169984, episodic return=113.84064483642578
# global step=172032, episodic return=104.88406372070312
# global step=172032, episodic return=115.4312973022461
# global step=172032, episodic return=115.14859771728516
# global step=172032, episodic return=74.9366455078125
# global step=172032, episodic return=116.0222396850586
# global step=172032, episodic return=112.48920440673828
# global step=172032, episodic return=121.92048645019531
# global step=172032, episodic return=114.99141693115234
# global step=172032, episodic return=106.04571533203125
# global step=172032, episodic return=117.00236511230469
# global step=172032, episodic return=109.08717346191406
# global step=172032, episodic return=103.71165466308594
# global step=172032, episodic return=110.03223419189453
# global step=172032, episodic return=116.25597381591797
# global step=174080, episodic return=122.5010757446289
# global step=174080, episodic return=101.1298599243164
# global step=174080, episodic return=114.83950805664062
# global step=174080, episodic return=98.94713592529297
# global step=174080, episodic return=104.3014144897461
# global step=174080, episodic return=121.6954345703125
# global step=174080, episodic return=123.40055084228516
# global step=174080, episodic return=101.3789291381836
# global step=174080, episodic return=119.3837890625
# global step=174080, episodic return=72.65702819824219
# global step=174080, episodic return=119.07827758789062
# global step=174080, episodic return=111.09452819824219
# global step=174080, episodic return=73.65735626220703
# global step=174080, episodic return=107.7371826171875
# global step=176128, episodic return=98.86298370361328
# global step=176128, episodic return=122.83103942871094
# global step=176128, episodic return=126.10395812988281
# global step=176128, episodic return=97.66522216796875
# global step=176128, episodic return=121.04720306396484
# global step=176128, episodic return=110.61449432373047
# global step=176128, episodic return=101.61279296875
# global step=176128, episodic return=94.282958984375
# global step=176128, episodic return=115.41055297851562
# global step=176128, episodic return=76.00065612792969
# global step=176128, episodic return=106.07003784179688
# global step=176128, episodic return=105.33540344238281
# global step=176128, episodic return=117.37117767333984
# global step=178176, episodic return=105.89568328857422
# global step=178176, episodic return=125.38764953613281
# global step=178176, episodic return=96.97624969482422
# global step=178176, episodic return=105.6686782836914
# global step=178176, episodic return=116.39730834960938
# global step=178176, episodic return=108.95430755615234
# global step=178176, episodic return=92.4764633178711
# global step=178176, episodic return=109.58208465576172
# global step=178176, episodic return=106.57112121582031
# global step=178176, episodic return=113.02086639404297
# global step=178176, episodic return=98.9554443359375
# global step=178176, episodic return=111.72582244873047
# global step=178176, episodic return=114.2882308959961
# global step=178176, episodic return=122.70337677001953
# global step=180224, episodic return=113.79070281982422
# global step=180224, episodic return=130.01449584960938
# global step=180224, episodic return=122.92782592773438
# global step=180224, episodic return=110.2484130859375
# global step=180224, episodic return=114.70101928710938
# global step=180224, episodic return=124.19140625
# global step=180224, episodic return=126.24955749511719
# global step=180224, episodic return=122.57467651367188
# global step=180224, episodic return=104.98390197753906
# global step=180224, episodic return=117.0591812133789
# global step=180224, episodic return=107.10230255126953
# global step=180224, episodic return=107.29594421386719
# global step=180224, episodic return=90.24313354492188
# global step=180224, episodic return=120.2119369506836
# global step=180224, episodic return=120.36652374267578
# global step=180224, episodic return=125.1673355102539
# global step=180224, episodic return=106.17817687988281
# global step=182272, episodic return=111.89273071289062
# global step=182272, episodic return=84.89623260498047
# global step=182272, episodic return=97.29293823242188
# global step=182272, episodic return=124.02271270751953
# global step=182272, episodic return=128.7617645263672
# global step=182272, episodic return=127.27131652832031
# global step=182272, episodic return=119.33697509765625
# global step=182272, episodic return=119.38399505615234
# global step=182272, episodic return=124.79883575439453
# global step=182272, episodic return=113.96041870117188
# global step=182272, episodic return=129.2040252685547
# global step=182272, episodic return=135.7779541015625
# global step=182272, episodic return=90.63514709472656
# global step=182272, episodic return=109.53429412841797
# global step=182272, episodic return=109.97126770019531
# global step=182272, episodic return=116.88907623291016
# global step=182272, episodic return=105.70587158203125
# global step=182272, episodic return=119.26686096191406
# global step=182272, episodic return=128.48155212402344
# global step=182272, episodic return=102.80235290527344
# global step=182272, episodic return=88.22254943847656
# global step=184320, episodic return=111.61331939697266
# global step=184320, episodic return=127.48506164550781
# global step=184320, episodic return=124.39280700683594
# global step=184320, episodic return=118.4390640258789
# global step=184320, episodic return=120.9752426147461
# global step=184320, episodic return=114.22577667236328
# global step=184320, episodic return=128.98342895507812
# global step=184320, episodic return=82.32896423339844
# global step=184320, episodic return=113.21060180664062
# global step=184320, episodic return=111.6923828125
# global step=184320, episodic return=103.03746795654297
# global step=184320, episodic return=122.41747283935547
# global step=184320, episodic return=112.22671508789062
# global step=184320, episodic return=96.35433197021484
# global step=184320, episodic return=131.65347290039062
# global step=184320, episodic return=116.37346649169922
# global step=184320, episodic return=129.4177703857422
# global step=186368, episodic return=108.96865844726562
# global step=186368, episodic return=134.648193359375
# global step=186368, episodic return=90.28805541992188
# global step=186368, episodic return=116.97433471679688
# global step=186368, episodic return=85.95704650878906
# global step=186368, episodic return=107.2916259765625
# global step=186368, episodic return=75.02397918701172
# global step=186368, episodic return=124.2554931640625
# global step=186368, episodic return=129.10870361328125
# global step=186368, episodic return=130.74269104003906
# global step=186368, episodic return=129.0145263671875
# global step=186368, episodic return=126.92121887207031
# global step=186368, episodic return=110.18616485595703
# global step=186368, episodic return=120.14485931396484
# global step=186368, episodic return=125.79242706298828
# global step=186368, episodic return=106.28093719482422
# global step=186368, episodic return=123.86260986328125
# global step=186368, episodic return=100.41149139404297
# global step=186368, episodic return=96.91177368164062
# global step=186368, episodic return=124.16685485839844
# global step=186368, episodic return=119.52778625488281
# global step=186368, episodic return=95.89024353027344
# global step=186368, episodic return=130.56472778320312
# global step=188416, episodic return=117.50386810302734
# global step=188416, episodic return=123.20106506347656
# global step=188416, episodic return=117.61416625976562
# global step=188416, episodic return=99.80030059814453
# global step=188416, episodic return=117.38756561279297
# global step=188416, episodic return=128.43594360351562
# global step=188416, episodic return=128.48060607910156
# global step=188416, episodic return=86.19772338867188
# global step=188416, episodic return=114.00797271728516
# global step=188416, episodic return=87.16069793701172
# global step=188416, episodic return=115.54582977294922
# global step=188416, episodic return=124.4006576538086
# global step=188416, episodic return=124.88851928710938
# global step=188416, episodic return=118.3399429321289
# global step=188416, episodic return=115.66277313232422
# global step=188416, episodic return=133.0701446533203
# global step=190464, episodic return=63.80461120605469
# global step=190464, episodic return=89.31591033935547
# global step=190464, episodic return=112.21541595458984
# global step=190464, episodic return=130.2029266357422
# global step=190464, episodic return=119.4773941040039
# global step=190464, episodic return=107.71932220458984
# global step=190464, episodic return=132.9482421875
# global step=190464, episodic return=124.00845336914062
# global step=190464, episodic return=116.5266342163086
# global step=190464, episodic return=121.87689971923828
# global step=190464, episodic return=121.3293685913086
# global step=190464, episodic return=116.70145416259766
# global step=190464, episodic return=93.41502380371094
# global step=192512, episodic return=119.31388092041016
# global step=192512, episodic return=100.38457489013672
# global step=192512, episodic return=93.86756896972656
# global step=192512, episodic return=87.95162963867188
# global step=192512, episodic return=56.49943161010742
# global step=192512, episodic return=127.0465087890625
# global step=192512, episodic return=123.27313995361328
# global step=192512, episodic return=119.6728515625
# global step=192512, episodic return=109.35025024414062
# global step=192512, episodic return=117.89674377441406
# ...
# global step=49641472, episodic return=2140.38818359375
# global step=49643520, episodic return=869.3776245117188
# global step=49645568, episodic return=973.478271484375
# global step=49647616, episodic return=2140.12451171875
# global step=49649664, episodic return=2108.412353515625
# global step=49649664, episodic return=733.699462890625
# global step=49649664, episodic return=609.9174194335938
# global step=49649664, episodic return=2137.328369140625
# global step=49651712, episodic return=1047.2525634765625
# global step=49651712, episodic return=2195.6171875
# global step=49653760, episodic return=2093.7587890625
# global step=49655808, episodic return=2199.634765625
# global step=49655808, episodic return=254.82852172851562
# global step=49657856, episodic return=720.8226928710938
# global step=49657856, episodic return=1545.6182861328125
# global step=49657856, episodic return=1938.4842529296875
# global step=49664000, episodic return=2099.963134765625
# global step=49664000, episodic return=2134.389892578125
# global step=49668096, episodic return=1487.66064453125
# global step=49668096, episodic return=1303.86865234375
# global step=49670144, episodic return=2124.941650390625
# global step=49670144, episodic return=1861.6744384765625
# global step=49670144, episodic return=2165.580078125
# global step=49672192, episodic return=1389.854736328125
# global step=49676288, episodic return=306.4293212890625
# global step=49680384, episodic return=1040.7540283203125
# global step=49682432, episodic return=2112.810791015625
# global step=49684480, episodic return=1396.1748046875
# global step=49686528, episodic return=1750.019775390625
# global step=49686528, episodic return=2112.642333984375
# global step=49686528, episodic return=2139.498046875
# global step=49688576, episodic return=1511.5908203125
# global step=49688576, episodic return=1344.974365234375
# global step=49688576, episodic return=2156.3037109375
# global step=49692672, episodic return=2138.6162109375
# global step=49694720, episodic return=1584.0748291015625
# global step=49694720, episodic return=288.3179626464844
# global step=49694720, episodic return=1493.6029052734375
# global step=49696768, episodic return=1077.3284912109375
# global step=49700864, episodic return=1076.462158203125
# global step=49700864, episodic return=2199.21826171875
# global step=49702912, episodic return=2007.605712890625
# global step=49704960, episodic return=2125.230224609375
# global step=49704960, episodic return=2186.834716796875
# global step=49707008, episodic return=2156.607666015625
# global step=49707008, episodic return=987.110107421875
# global step=49707008, episodic return=1607.485595703125
# global step=49707008, episodic return=2177.891845703125
# global step=49707008, episodic return=2114.650146484375
# global step=49709056, episodic return=747.784912109375
# global step=49711104, episodic return=2204.377685546875
# global step=49711104, episodic return=1898.3817138671875
# global step=49713152, episodic return=2146.2998046875
# global step=49715200, episodic return=2161.860107421875
# global step=49715200, episodic return=2154.16064453125
# global step=49715200, episodic return=2146.206298828125
# global step=49715200, episodic return=1002.213134765625
# global step=49717248, episodic return=951.6305541992188
# global step=49717248, episodic return=1357.9559326171875
# global step=49717248, episodic return=1352.0621337890625
# global step=49717248, episodic return=747.6695556640625
# global step=49719296, episodic return=2146.4306640625
# global step=49719296, episodic return=764.7056274414062
# global step=49723392, episodic return=1550.96337890625
# global step=49723392, episodic return=1985.1097412109375
# global step=49725440, episodic return=2184.4423828125
# global step=49727488, episodic return=2197.9677734375
# global step=49727488, episodic return=2104.535400390625
# global step=49727488, episodic return=2105.156494140625
# global step=49729536, episodic return=2171.018310546875
# global step=49731584, episodic return=1545.6051025390625
# global step=49731584, episodic return=1460.4482421875
# global step=49733632, episodic return=2121.179443359375
# global step=49733632, episodic return=1633.1529541015625
# global step=49737728, episodic return=2147.77978515625
# global step=49739776, episodic return=2112.532470703125
# global step=49743872, episodic return=2175.040771484375
# global step=49745920, episodic return=2197.474365234375
# global step=49745920, episodic return=2162.377685546875
# global step=49747968, episodic return=534.3016967773438
# global step=49747968, episodic return=2200.1396484375
# global step=49750016, episodic return=2214.471435546875
# global step=49750016, episodic return=2165.848876953125
# global step=49752064, episodic return=838.7520751953125
# global step=49752064, episodic return=1603.4598388671875
# global step=49752064, episodic return=1966.697509765625
# global step=49754112, episodic return=1754.3773193359375
# global step=49754112, episodic return=1185.7640380859375
# global step=49754112, episodic return=1384.6480712890625
# global step=49756160, episodic return=1398.1131591796875
# global step=49756160, episodic return=782.88330078125
# global step=49760256, episodic return=2201.350830078125
# global step=49760256, episodic return=2210.54345703125
# global step=49760256, episodic return=2184.315673828125
# global step=49760256, episodic return=2150.086181640625
# global step=49762304, episodic return=2175.76171875
# global step=49762304, episodic return=2124.142578125
# global step=49762304, episodic return=1425.6563720703125
# global step=49762304, episodic return=2165.491455078125
# global step=49762304, episodic return=2179.546875
# global step=49762304, episodic return=1442.7578125
# global step=49762304, episodic return=1249.9937744140625
# global step=49762304, episodic return=2115.083251953125
# global step=49762304, episodic return=1619.997802734375
# global step=49764352, episodic return=1397.8973388671875
# global step=49766400, episodic return=2194.60302734375
# global step=49766400, episodic return=1249.391845703125
# global step=49768448, episodic return=2170.349853515625
# global step=49768448, episodic return=1391.5640869140625
# global step=49770496, episodic return=1926.586181640625
# global step=49770496, episodic return=2132.925048828125
# global step=49770496, episodic return=2155.49169921875
# global step=49770496, episodic return=2186.868408203125
# global step=49772544, episodic return=1864.6385498046875
# global step=49772544, episodic return=2126.191162109375
# global step=49774592, episodic return=2171.839111328125
# global step=49776640, episodic return=2215.29345703125
# global step=49778688, episodic return=1548.2401123046875
# global step=49780736, episodic return=2171.70166015625
# global step=49780736, episodic return=1502.3109130859375
# global step=49780736, episodic return=2174.06201171875
# global step=49782784, episodic return=1269.4783935546875
# global step=49782784, episodic return=1512.6278076171875
# global step=49786880, episodic return=2198.813232421875
# global step=49786880, episodic return=1436.3831787109375
# global step=49788928, episodic return=1262.4105224609375
# global step=49788928, episodic return=2118.43505859375
# global step=49788928, episodic return=2134.505859375
# global step=49790976, episodic return=2169.69384765625
# global step=49790976, episodic return=1213.8370361328125
# global step=49793024, episodic return=2158.56982421875
# global step=49793024, episodic return=2144.7578125
# global step=49795072, episodic return=1338.6973876953125
# global step=49795072, episodic return=2165.198486328125
# global step=49795072, episodic return=2118.065673828125
# global step=49795072, episodic return=1604.915283203125
# global step=49797120, episodic return=1592.9615478515625
# global step=49797120, episodic return=936.166259765625
# global step=49799168, episodic return=849.825439453125
# global step=49799168, episodic return=1349.701416015625
# global step=49801216, episodic return=1658.205322265625
# global step=49801216, episodic return=460.8278503417969
# global step=49801216, episodic return=2199.070556640625
# global step=49803264, episodic return=1519.5166015625
# global step=49805312, episodic return=2062.763427734375
# global step=49807360, episodic return=266.8512268066406
# global step=49807360, episodic return=2186.702880859375
# global step=49809408, episodic return=1692.63330078125
# global step=49809408, episodic return=1174.327880859375
# global step=49809408, episodic return=928.2695922851562
# global step=49809408, episodic return=2170.329833984375
# global step=49809408, episodic return=2204.52880859375
# global step=49811456, episodic return=669.3998413085938
# global step=49813504, episodic return=2190.675537109375
# global step=49813504, episodic return=1672.7789306640625
# global step=49813504, episodic return=1225.4105224609375
# global step=49817600, episodic return=1518.0445556640625
# global step=49819648, episodic return=2137.10400390625
# global step=49819648, episodic return=682.2791748046875
# global step=49819648, episodic return=2199.65625
# global step=49821696, episodic return=1211.6900634765625
# global step=49821696, episodic return=2198.126953125
# global step=49821696, episodic return=2150.340576171875
# global step=49823744, episodic return=545.6110229492188
# global step=49823744, episodic return=2168.25634765625
# global step=49823744, episodic return=601.7528076171875
# global step=49827840, episodic return=2186.529052734375
# global step=49827840, episodic return=1554.8216552734375
# global step=49829888, episodic return=2119.282470703125
# global step=49829888, episodic return=972.786865234375
# global step=49831936, episodic return=2142.09814453125
# global step=49833984, episodic return=2196.599365234375
# global step=49838080, episodic return=1488.67919921875
# global step=49838080, episodic return=2208.37890625
# global step=49844224, episodic return=2230.862060546875
# global step=49846272, episodic return=1467.51171875
# global step=49846272, episodic return=1271.3134765625
# global step=49846272, episodic return=2184.572998046875
# global step=49848320, episodic return=2169.45703125
# global step=49848320, episodic return=2146.386474609375
# global step=49848320, episodic return=2200.634033203125
# global step=49848320, episodic return=2175.798828125
# global step=49850368, episodic return=2175.668212890625
# global step=49850368, episodic return=1628.768798828125
# global step=49852416, episodic return=2155.64306640625
# global step=49852416, episodic return=2202.437744140625
# global step=49854464, episodic return=2199.363037109375
# global step=49858560, episodic return=2188.780029296875
# global step=49862656, episodic return=2156.9697265625
# global step=49862656, episodic return=2199.4931640625
# global step=49864704, episodic return=1413.86962890625
# global step=49870848, episodic return=1828.986328125
# global step=49870848, episodic return=2163.33447265625
# global step=49872896, episodic return=2169.38671875
# global step=49872896, episodic return=2177.31884765625
# global step=49872896, episodic return=292.6189880371094
# global step=49874944, episodic return=286.7741394042969
# global step=49876992, episodic return=1683.306640625
# global step=49876992, episodic return=2200.271728515625
# global step=49876992, episodic return=2201.398681640625
# global step=49876992, episodic return=2112.797607421875
# global step=49883136, episodic return=2154.49560546875
# global step=49883136, episodic return=2196.9013671875
# global step=49885184, episodic return=1711.303955078125
# global step=49887232, episodic return=2182.857177734375
# global step=49887232, episodic return=2182.338134765625
# global step=49889280, episodic return=2141.253662109375
# global step=49891328, episodic return=2184.639404296875
# global step=49893376, episodic return=1875.418212890625
# global step=49893376, episodic return=291.2927551269531
# global step=49895424, episodic return=2166.402587890625
# global step=49895424, episodic return=2119.021728515625
# global step=49897472, episodic return=2178.9052734375
# global step=49897472, episodic return=1407.63037109375
# global step=49899520, episodic return=2210.109130859375
# global step=49901568, episodic return=1063.2042236328125
# global step=49903616, episodic return=2167.83984375
# global step=49903616, episodic return=1841.845703125
# global step=49903616, episodic return=2217.914306640625
# global step=49907712, episodic return=2202.5732421875
# global step=49907712, episodic return=2210.658203125
# global step=49909760, episodic return=1268.468017578125
# global step=49909760, episodic return=950.796142578125
# global step=49909760, episodic return=988.032470703125
# global step=49911808, episodic return=2189.75439453125
# global step=49913856, episodic return=2180.818115234375
# global step=49913856, episodic return=415.8505859375
# global step=49917952, episodic return=2145.117431640625
# global step=49920000, episodic return=470.95458984375
# global step=49920000, episodic return=2138.53662109375
# global step=49920000, episodic return=1361.413330078125
# global step=49922048, episodic return=1559.21044921875
# global step=49922048, episodic return=1342.5570068359375
# global step=49924096, episodic return=1461.3387451171875
# global step=49926144, episodic return=2131.9443359375
# global step=49926144, episodic return=1012.7424926757812
# global step=49926144, episodic return=2178.337158203125
# global step=49930240, episodic return=2002.3292236328125
# global step=49930240, episodic return=2125.7607421875
# global step=49932288, episodic return=1785.033203125
# global step=49932288, episodic return=2219.268798828125
# global step=49932288, episodic return=2192.636962890625
# global step=49934336, episodic return=1725.7869873046875
# global step=49934336, episodic return=1253.0748291015625
# global step=49936384, episodic return=2192.00830078125
# global step=49936384, episodic return=2150.988525390625
# global step=49936384, episodic return=2130.50537109375
# global step=49936384, episodic return=937.1102905273438
# global step=49940480, episodic return=2151.11669921875
# global step=49940480, episodic return=1714.6502685546875
# global step=49940480, episodic return=2206.35693359375
# global step=49942528, episodic return=2185.970458984375
# global step=49942528, episodic return=948.74560546875
# global step=49942528, episodic return=1126.9200439453125
# global step=49944576, episodic return=569.6993408203125
# global step=49944576, episodic return=2160.44384765625
# global step=49946624, episodic return=1748.6597900390625
# global step=49946624, episodic return=1815.6741943359375
# global step=49946624, episodic return=2164.392333984375
# global step=49946624, episodic return=2165.018310546875
# global step=49948672, episodic return=1696.1865234375
# global step=49948672, episodic return=2144.048095703125
# global step=49948672, episodic return=2136.52294921875
# global step=49950720, episodic return=1039.462890625
# global step=49954816, episodic return=1740.900634765625
# global step=49954816, episodic return=2048.376953125
# global step=49963008, episodic return=2183.864013671875
# global step=49965056, episodic return=1889.7222900390625
# global step=49967104, episodic return=602.28857421875
# global step=49969152, episodic return=1605.639404296875
# global step=49971200, episodic return=2148.525146484375
# global step=49973248, episodic return=2072.439453125
# global step=49973248, episodic return=603.096923828125
# global step=49973248, episodic return=2177.788330078125
# global step=49975296, episodic return=2152.6171875
# global step=49977344, episodic return=1095.3016357421875
# global step=49977344, episodic return=1825.2108154296875
# global step=49977344, episodic return=1693.6260986328125
# global step=49977344, episodic return=2098.91162109375
# global step=49977344, episodic return=2178.68896484375
# global step=49979392, episodic return=2207.24755859375
# global step=49979392, episodic return=1269.01904296875
# global step=49979392, episodic return=2168.141357421875
# global step=49981440, episodic return=1540.619140625
# global step=49983488, episodic return=2183.501953125
# global step=49983488, episodic return=2187.55810546875
# global step=49989632, episodic return=1220.9879150390625
# global step=49991680, episodic return=1518.9525146484375

# %%
params = out['runner_state'][0].params

# %%
import pickle
with open("../results/experts/brax_hopper/fn_params.pkl", "wb") as f:
    pickle.dump(params, f)
