# %%
from stanza.runtime import setup
setup()

# %%
from stanza.datasets.vision import image_datasets
from stanza.canvas import image_grid
from stanza.util.ipython import as_image
from IPython.display import display

mnist = image_datasets.create("mnist")
cifar10 = image_datasets.create("cifar/cifar10")
cifar100 = image_datasets.create("cifar/cifar100")
celeb_a = image_datasets.create("celeb_a")

mnist_image = image_grid(mnist.splits["train"].slice(0,64).as_pytree().pixels)
cifar10_image = image_grid(cifar10.splits["train"].slice(0,64).as_pytree().pixels)
cifar100_image = image_grid(cifar100.splits["train"].slice(0,64).as_pytree().pixels)
celeb_a_image = image_grid(celeb_a.splits["train"].slice(0,16).as_pytree().pixels)

display(as_image(mnist_image))
display(as_image(cifar10_image))
display(as_image(cifar100_image))
display(as_image(celeb_a_image))
