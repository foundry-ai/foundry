# %%
# %load_ext autoreload
# %autoreload 2
# %aimport -jax
# %aimport -jaxlib

# %%
import jax
import jax.numpy as jnp
import chex
import numpy as np
from flax import struct
from functools import partial
from typing import Optional, Tuple, Union, Any
from gymnax.environments import environment, spaces
from brax import envs
from brax.envs.wrappers.training import EpisodeWrapper, AutoResetWrapper

class GymnaxWrapper(object):
    """Base class for Gymnax wrappers."""

    def __init__(self, env):
        self._env = env

    # provide proxy access to regular attributes of wrapped object
    def __getattr__(self, name):
        return getattr(self._env, name)

class FlattenObservationWrapper(GymnaxWrapper):
    """Flatten the observations of the environment."""

    def __init__(self, env: environment.Environment):
        super().__init__(env)

    def observation_space(self, params) -> spaces.Box:
        assert isinstance(
            self._env.observation_space(params), spaces.Box
        ), "Only Box spaces are supported for now."
        return spaces.Box(
            low=self._env.observation_space(params).low,
            high=self._env.observation_space(params).high,
            shape=(np.prod(self._env.observation_space(params).shape),),
            dtype=self._env.observation_space(params).dtype,
        )

    @partial(jax.jit, static_argnums=(0,))
    def reset(
        self, key: chex.PRNGKey, params: Optional[environment.EnvParams] = None
    ) -> Tuple[chex.Array, environment.EnvState]:
        obs, state = self._env.reset(key, params)
        obs = jnp.reshape(obs, (-1,))
        return obs, state

    @partial(jax.jit, static_argnums=(0,))
    def step(
        self,
        key: chex.PRNGKey,
        state: environment.EnvState,
        action: Union[int, float],
        params: Optional[environment.EnvParams] = None,
    ) -> Tuple[chex.Array, environment.EnvState, float, bool, dict]:
        obs, state, reward, done, info = self._env.step(key, state, action, params)
        obs = jnp.reshape(obs, (-1,))
        return obs, state, reward, done, info


@struct.dataclass
class LogEnvState:
    env_state: environment.EnvState
    episode_returns: float
    episode_lengths: int
    returned_episode_returns: float
    returned_episode_lengths: int
    timestep: int


class LogWrapper(GymnaxWrapper):
    """Log the episode returns and lengths."""

    def __init__(self, env: environment.Environment):
        super().__init__(env)

    @partial(jax.jit, static_argnums=(0,))
    def reset(
        self, key: chex.PRNGKey, params: Optional[environment.EnvParams] = None
    ) -> Tuple[chex.Array, environment.EnvState]:
        obs, env_state = self._env.reset(key, params)
        state = LogEnvState(env_state, 0, 0, 0, 0, 0)
        return obs, state

    @partial(jax.jit, static_argnums=(0,))
    def step(
        self,
        key: chex.PRNGKey,
        state: environment.EnvState,
        action: Union[int, float],
        params: Optional[environment.EnvParams] = None,
    ) -> Tuple[chex.Array, environment.EnvState, float, bool, dict]:
        obs, env_state, reward, done, info = self._env.step(
            key, state.env_state, action, params
        )
        new_episode_return = state.episode_returns + reward
        new_episode_length = state.episode_lengths + 1
        state = LogEnvState(
            env_state=env_state,
            episode_returns=new_episode_return * (1 - done),
            episode_lengths=new_episode_length * (1 - done),
            returned_episode_returns=state.returned_episode_returns * (1 - done)
            + new_episode_return * done,
            returned_episode_lengths=state.returned_episode_lengths * (1 - done)
            + new_episode_length * done,
            timestep=state.timestep + 1,
        )
        info["returned_episode_returns"] = state.returned_episode_returns
        info["returned_episode_lengths"] = state.returned_episode_lengths
        info["timestep"] = state.timestep
        info["returned_episode"] = done
        return obs, state, reward, done, info


class BraxGymnaxWrapper:
    def __init__(self, env_name, backend="positional"):
        env = envs.get_environment(env_name=env_name, backend=backend)
        env = EpisodeWrapper(env, episode_length=1000, action_repeat=1)
        env = AutoResetWrapper(env)
        self._env = env
        self.action_size = env.action_size
        self.observation_size = (env.observation_size,)

    def reset(self, key, params=None):
        state = self._env.reset(key)
        return state.obs, state

    def step(self, key, state, action, params=None):
        next_state = self._env.step(state, action)
        return next_state.obs, next_state, next_state.reward, next_state.done > 0.5, {}

    def observation_space(self, params):
        return spaces.Box(
            low=-jnp.inf,
            high=jnp.inf,
            shape=(self._env.observation_size,),
        )

    def action_space(self, params):
        return spaces.Box(
            low=-1.0,
            high=1.0,
            shape=(self._env.action_size,),
        )


class ClipAction(GymnaxWrapper):
    def __init__(self, env, low=-1.0, high=1.0):
        super().__init__(env)
        self.low = low
        self.high = high

    def step(self, key, state, action, params=None):
        """TODO: In theory the below line should be the way to do this."""
        # action = jnp.clip(action, self.env.action_space.low, self.env.action_space.high)
        action = jnp.clip(action, self.low, self.high)
        return self._env.step(key, state, action, params)


class TransformObservation(GymnaxWrapper):
    def __init__(self, env, transform_obs):
        super().__init__(env)
        self.transform_obs = transform_obs

    def reset(self, key, params=None):
        obs, state = self._env.reset(key, params)
        return self.transform_obs(obs), state

    def step(self, key, state, action, params=None):
        obs, state, reward, done, info = self._env.step(key, state, action, params)
        return self.transform_obs(obs), state, reward, done, info

class TransformReward(GymnaxWrapper):
    def __init__(self, env, transform_reward):
        super().__init__(env)
        self.transform_reward = transform_reward

    def step(self, key, state, action, params=None):
        obs, state, reward, done, info = self._env.step(key, state, action, params)
        return obs, state, self.transform_reward(reward), done, info


class VecEnv(GymnaxWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.reset = jax.vmap(self._env.reset, in_axes=(0, None))
        self.step = jax.vmap(self._env.step, in_axes=(0, 0, 0, None))


@struct.dataclass
class NormalizeVecObsEnvState:
    mean: jnp.ndarray
    var: jnp.ndarray
    count: float
    env_state: environment.EnvState


class NormalizeVecObservation(GymnaxWrapper):
    def __init__(self, env):
        super().__init__(env)

    def reset(self, key, params=None):
        obs, state = self._env.reset(key, params)
        state = NormalizeVecObsEnvState(
            mean=jnp.zeros_like(obs),
            var=jnp.ones_like(obs),
            count=1e-4,
            env_state=state,
        )
        batch_mean = jnp.mean(obs, axis=0)
        batch_var = jnp.var(obs, axis=0)
        batch_count = obs.shape[0]

        delta = batch_mean - state.mean
        tot_count = state.count + batch_count

        new_mean = state.mean + delta * batch_count / tot_count
        m_a = state.var * state.count
        m_b = batch_var * batch_count
        M2 = m_a + m_b + jnp.square(delta) * state.count * batch_count / tot_count
        new_var = M2 / tot_count
        new_count = tot_count

        state = NormalizeVecObsEnvState(
            mean=new_mean,
            var=new_var,
            count=new_count,
            env_state=state.env_state,
        )

        return (obs - state.mean) / jnp.sqrt(state.var + 1e-8), state

    def step(self, key, state, action, params=None):
        obs, env_state, reward, done, info = self._env.step(
            key, state.env_state, action, params
        )

        batch_mean = jnp.mean(obs, axis=0)
        batch_var = jnp.var(obs, axis=0)
        batch_count = obs.shape[0]

        delta = batch_mean - state.mean
        tot_count = state.count + batch_count

        new_mean = state.mean + delta * batch_count / tot_count
        m_a = state.var * state.count
        m_b = batch_var * batch_count
        M2 = m_a + m_b + jnp.square(delta) * state.count * batch_count / tot_count
        new_var = M2 / tot_count
        new_count = tot_count

        state = NormalizeVecObsEnvState(
            mean=new_mean,
            var=new_var,
            count=new_count,
            env_state=env_state,
        )
        return (
            (obs - state.mean) / jnp.sqrt(state.var + 1e-8),
            state,
            reward,
            done,
            info,
        )


@struct.dataclass
class NormalizeVecRewEnvState:
    mean: jnp.ndarray
    var: jnp.ndarray
    count: float
    return_val: float
    env_state: environment.EnvState


class NormalizeVecReward(GymnaxWrapper):
    def __init__(self, env, gamma):
        super().__init__(env)
        self.gamma = gamma

    def reset(self, key, params=None):
        obs, state = self._env.reset(key, params)
        batch_count = obs.shape[0]
        state = NormalizeVecRewEnvState(
            mean=0.0,
            var=1.0,
            count=1e-4,
            return_val=jnp.zeros((batch_count,)),
            env_state=state,
        )
        return obs, state

    def step(self, key, state, action, params=None):
        obs, env_state, reward, done, info = self._env.step(
            key, state.env_state, action, params
        )
        return_val = state.return_val * self.gamma * (1 - done) + reward

        batch_mean = jnp.mean(return_val, axis=0)
        batch_var = jnp.var(return_val, axis=0)
        batch_count = obs.shape[0]

        delta = batch_mean - state.mean
        tot_count = state.count + batch_count

        new_mean = state.mean + delta * batch_count / tot_count
        m_a = state.var * state.count
        m_b = batch_var * batch_count
        M2 = m_a + m_b + jnp.square(delta) * state.count * batch_count / tot_count
        new_var = M2 / tot_count
        new_count = tot_count

        state = NormalizeVecRewEnvState(
            mean=new_mean,
            var=new_var,
            count=new_count,
            return_val=return_val,
            env_state=env_state,
        )
        return obs, state, reward / jnp.sqrt(state.var + 1e-8), done, info

# %%
import jax
import jax.numpy as jnp
import flax.linen as nn
import numpy as np
import optax
from flax.linen.initializers import constant, orthogonal
from typing import Sequence, NamedTuple, Any
from flax.training.train_state import TrainState
import distrax

class ActorCritic(nn.Module):
    action_dim: Sequence[int]
    activation: str = "tanh"

    @nn.compact
    def __call__(self, x):
        if self.activation == "relu":
            activation = nn.relu
        else:
            activation = nn.tanh
        actor_mean = nn.Dense(
            256, kernel_init=orthogonal(np.sqrt(2)), bias_init=constant(0.0)
        )(x)
        actor_mean = activation(actor_mean)
        actor_mean = nn.Dense(
            256, kernel_init=orthogonal(np.sqrt(2)), bias_init=constant(0.0)
        )(actor_mean)
        actor_mean = activation(actor_mean)
        actor_mean = nn.Dense(
            self.action_dim, kernel_init=orthogonal(0.01), bias_init=constant(0.0)
        )(actor_mean)
        actor_logtstd = self.param("log_std", nn.initializers.zeros, (self.action_dim,))
        pi = distrax.MultivariateNormalDiag(actor_mean, jnp.exp(actor_logtstd))

        critic = nn.Dense(
            256, kernel_init=orthogonal(np.sqrt(2)), bias_init=constant(0.0)
        )(x)
        critic = activation(critic)
        critic = nn.Dense(
            256, kernel_init=orthogonal(np.sqrt(2)), bias_init=constant(0.0)
        )(critic)
        critic = activation(critic)
        critic = nn.Dense(1, kernel_init=orthogonal(1.0), bias_init=constant(0.0))(
            critic
        )

        return pi, jnp.squeeze(critic, axis=-1)


class Transition(NamedTuple):
    done: jnp.ndarray
    action: jnp.ndarray
    value: jnp.ndarray
    reward: jnp.ndarray
    log_prob: jnp.ndarray
    obs: jnp.ndarray
    info: jnp.ndarray


def make_train(config):
    config["NUM_UPDATES"] = (
        config["TOTAL_TIMESTEPS"] // config["NUM_STEPS"] // config["NUM_ENVS"]
    )
    config["MINIBATCH_SIZE"] = (
        config["NUM_ENVS"] * config["NUM_STEPS"] // config["NUM_MINIBATCHES"]
    )
    print(config["MINIBATCH_SIZE"])
    env, env_params = BraxGymnaxWrapper(config["ENV_NAME"]), None
    env = LogWrapper(env)
    env = ClipAction(env)
    env = VecEnv(env)
    if config["NORMALIZE_ENV"]:
        env = NormalizeVecObservation(env)
        env = NormalizeVecReward(env, config["GAMMA"])

    def linear_schedule(count):
        frac = (
            1.0
            - (count // (config["NUM_MINIBATCHES"] * config["UPDATE_EPOCHS"]))
            / config["NUM_UPDATES"]
        )
        return config["LR"] * frac

    def train(rng):
        # INIT NETWORK
        network = ActorCritic(
            env.action_space(env_params).shape[0], activation=config["ACTIVATION"]
        )
        rng, _rng = jax.random.split(rng)
        init_x = jnp.zeros(env.observation_space(env_params).shape)
        network_params = network.init(_rng, init_x)
        if config["ANNEAL_LR"]:
            tx = optax.chain(
                optax.clip_by_global_norm(config["MAX_GRAD_NORM"]),
                optax.adam(learning_rate=linear_schedule, eps=1e-5),
            )
        else:
            tx = optax.chain(
                optax.clip_by_global_norm(config["MAX_GRAD_NORM"]),
                optax.adam(config["LR"], eps=1e-5),
            )
        train_state = TrainState.create(
            apply_fn=network.apply,
            params=network_params,
            tx=tx,
        )

        # INIT ENV
        rng, _rng = jax.random.split(rng)
        reset_rng = jax.random.split(_rng, config["NUM_ENVS"])
        obsv, env_state = env.reset(reset_rng, env_params)

        # TRAIN LOOP
        def _update_step(runner_state, unused):
            # COLLECT TRAJECTORIES
            def _env_step(runner_state, unused):
                train_state, env_state, last_obs, rng = runner_state

                # SELECT ACTION
                rng, _rng = jax.random.split(rng)
                pi, value = network.apply(train_state.params, last_obs)
                action = pi.sample(seed=_rng)
                log_prob = pi.log_prob(action)

                # STEP ENV
                rng, _rng = jax.random.split(rng)
                rng_step = jax.random.split(_rng, config["NUM_ENVS"])
                obsv, env_state, reward, done, info = env.step(
                    rng_step, env_state, action, env_params
                )
                transition = Transition(
                    done, action, value, reward, log_prob, last_obs, info
                )
                runner_state = (train_state, env_state, obsv, rng)
                return runner_state, transition

            runner_state, traj_batch = jax.lax.scan(
                _env_step, runner_state, None, config["NUM_STEPS"]
            )

            # CALCULATE ADVANTAGE
            train_state, env_state, last_obs, rng = runner_state
            _, last_val = network.apply(train_state.params, last_obs)

            def _calculate_gae(traj_batch, last_val):
                def _get_advantages(gae_and_next_value, transition):
                    gae, next_value = gae_and_next_value
                    done, value, reward = (
                        transition.done,
                        transition.value,
                        transition.reward,
                    )
                    delta = reward + config["GAMMA"] * next_value * (1 - done) - value
                    gae = (
                        delta
                        + config["GAMMA"] * config["GAE_LAMBDA"] * (1 - done) * gae
                    )
                    return (gae, value), gae

                _, advantages = jax.lax.scan(
                    _get_advantages,
                    (jnp.zeros_like(last_val), last_val),
                    traj_batch,
                    reverse=True,
                    unroll=16,
                )
                return advantages, advantages + traj_batch.value

            advantages, targets = _calculate_gae(traj_batch, last_val)

            # UPDATE NETWORK
            def _update_epoch(update_state, unused):
                def _update_minbatch(train_state, batch_info):
                    traj_batch, advantages, targets = batch_info

                    def _loss_fn(params, traj_batch, gae, targets):
                        # RERUN NETWORK
                        pi, value = network.apply(params, traj_batch.obs)
                        log_prob = pi.log_prob(traj_batch.action)

                        # CALCULATE VALUE LOSS
                        value_pred_clipped = traj_batch.value + (
                            value - traj_batch.value
                        ).clip(-config["CLIP_EPS"], config["CLIP_EPS"])
                        value_losses = jnp.square(value - targets)
                        value_losses_clipped = jnp.square(value_pred_clipped - targets)
                        value_loss = (
                            0.5 * jnp.maximum(value_losses, value_losses_clipped).mean()
                        )

                        # CALCULATE ACTOR LOSS
                        ratio = jnp.exp(log_prob - traj_batch.log_prob)
                        gae = (gae - gae.mean()) / (gae.std() + 1e-8)
                        loss_actor1 = ratio * gae
                        loss_actor2 = (
                            jnp.clip(
                                ratio,
                                1.0 - config["CLIP_EPS"],
                                1.0 + config["CLIP_EPS"],
                            )
                            * gae
                        )
                        loss_actor = -jnp.minimum(loss_actor1, loss_actor2)
                        loss_actor = loss_actor.mean()
                        entropy = pi.entropy().mean()

                        total_loss = (
                            loss_actor
                            + config["VF_COEF"] * value_loss
                            - config["ENT_COEF"] * entropy
                        )
                        return total_loss, (value_loss, loss_actor, entropy)

                    grad_fn = jax.value_and_grad(_loss_fn, has_aux=True)
                    total_loss, grads = grad_fn(
                        train_state.params, traj_batch, advantages, targets
                    )
                    train_state = train_state.apply_gradients(grads=grads)
                    return train_state, total_loss

                train_state, traj_batch, advantages, targets, rng = update_state
                rng, _rng = jax.random.split(rng)
                batch_size = config["MINIBATCH_SIZE"] * config["NUM_MINIBATCHES"]
                assert (
                    batch_size == config["NUM_STEPS"] * config["NUM_ENVS"]
                ), "batch size must be equal to number of steps * number of envs"
                permutation = jax.random.permutation(_rng, batch_size)
                batch = (traj_batch, advantages, targets)
                batch = jax.tree_util.tree_map(
                    lambda x: x.reshape((batch_size,) + x.shape[2:]), batch
                )
                shuffled_batch = jax.tree_util.tree_map(
                    lambda x: jnp.take(x, permutation, axis=0), batch
                )
                minibatches = jax.tree_util.tree_map(
                    lambda x: jnp.reshape(
                        x, [config["NUM_MINIBATCHES"], -1] + list(x.shape[1:])
                    ),
                    shuffled_batch,
                )
                train_state, total_loss = jax.lax.scan(
                    _update_minbatch, train_state, minibatches
                )
                update_state = (train_state, traj_batch, advantages, targets, rng)
                return update_state, total_loss

            update_state = (train_state, traj_batch, advantages, targets, rng)
            update_state, loss_info = jax.lax.scan(
                _update_epoch, update_state, None, config["UPDATE_EPOCHS"]
            )
            train_state = update_state[0]
            metric = traj_batch.info
            rng = update_state[-1]
            if config.get("DEBUG"):

                def callback(info):
                    return_values = info["returned_episode_returns"][
                        info["returned_episode"]
                    ]
                    timesteps = (
                        info["timestep"][info["returned_episode"]] * config["NUM_ENVS"]
                    )
                    for t in range(len(timesteps)):
                        print(
                            f"global step={timesteps[t]}, episodic return={return_values[t]}"
                        )

                jax.debug.callback(callback, metric)

            runner_state = (train_state, env_state, last_obs, rng)
            return runner_state, metric

        rng, _rng = jax.random.split(rng)
        runner_state = (train_state, env_state, obsv, _rng)
        print(config["NUM_UPDATES"])
        runner_state, metric = jax.lax.scan(
            _update_step, runner_state, None, config["NUM_UPDATES"]
        )
        return {"runner_state": runner_state, "metrics": metric}

    return train

# %%
if __name__ == "__main__":
    config = {
        "LR": 3e-4,
        "NUM_ENVS": 2048,
        "NUM_STEPS": 10,
        "TOTAL_TIMESTEPS": 1e6,
        "UPDATE_EPOCHS": 4,
        "NUM_MINIBATCHES": 32,
        "GAMMA": 0.99,
        "GAE_LAMBDA": 0.95,
        "CLIP_EPS": 0.2,
        "ENT_COEF": 0.0,
        "VF_COEF": 0.5,
        "MAX_GRAD_NORM": 0.5,
        "ACTIVATION": "tanh",
        "ENV_NAME": "hopper",
        "ANNEAL_LR": False,
        "NORMALIZE_ENV": True,
        "DEBUG": True,
    }
    rng = jax.random.PRNGKey(30)
    train_jit = jax.jit(make_train(config))
    out = train_jit(rng)
# Out:
# 640
# global step=20480, episodic return=10.685184478759766
# global step=20480, episodic return=10.193788528442383
# global step=22528, episodic return=13.865494728088379
# global step=22528, episodic return=13.209982872009277
# global step=24576, episodic return=12.73769760131836
# global step=24576, episodic return=14.7815580368042
# global step=24576, episodic return=12.181407928466797
# global step=24576, episodic return=12.076610565185547
# global step=24576, episodic return=16.389331817626953
# global step=24576, episodic return=13.50681209564209
# global step=24576, episodic return=14.988597869873047
# global step=26624, episodic return=14.535443305969238
# global step=26624, episodic return=16.717872619628906
# global step=26624, episodic return=13.292655944824219
# global step=28672, episodic return=9.311372756958008
# global step=28672, episodic return=16.13484001159668
# global step=28672, episodic return=15.585590362548828
# global step=28672, episodic return=14.106359481811523
# global step=28672, episodic return=18.181621551513672
# global step=28672, episodic return=15.484583854675293
# global step=28672, episodic return=10.57589054107666
# global step=28672, episodic return=16.038917541503906
# global step=28672, episodic return=15.555374145507812
# global step=28672, episodic return=15.318741798400879
# global step=28672, episodic return=16.778207778930664
# global step=30720, episodic return=18.831544876098633
# global step=30720, episodic return=15.417978286743164
# global step=30720, episodic return=16.29878807067871
# global step=30720, episodic return=16.01799774169922
# global step=30720, episodic return=15.797218322753906
# global step=30720, episodic return=19.427040100097656
# global step=30720, episodic return=17.66497230529785
# global step=30720, episodic return=16.027341842651367
# global step=30720, episodic return=18.500625610351562
# global step=30720, episodic return=16.31158447265625
# global step=30720, episodic return=20.456165313720703
# global step=30720, episodic return=15.00316333770752
# global step=30720, episodic return=18.90085792541504
# global step=30720, episodic return=21.122814178466797
# global step=30720, episodic return=16.96462631225586
# global step=30720, episodic return=13.470561981201172
# global step=30720, episodic return=19.564041137695312
# global step=30720, episodic return=12.300593376159668
# global step=32768, episodic return=16.46110725402832
# global step=32768, episodic return=15.961688995361328
# global step=32768, episodic return=21.151905059814453
# global step=32768, episodic return=21.155502319335938
# global step=32768, episodic return=15.561958312988281
# global step=32768, episodic return=15.597442626953125
# global step=32768, episodic return=16.131990432739258
# global step=32768, episodic return=19.92121696472168
# global step=32768, episodic return=22.64759063720703
# global step=32768, episodic return=17.202417373657227
# global step=32768, episodic return=21.183277130126953
# global step=32768, episodic return=21.489437103271484
# global step=32768, episodic return=22.100290298461914
# global step=32768, episodic return=12.65295124053955
# global step=32768, episodic return=15.768306732177734
# global step=32768, episodic return=18.660419464111328
# global step=32768, episodic return=19.342132568359375
# global step=32768, episodic return=16.560386657714844
# global step=32768, episodic return=16.73118782043457
# global step=32768, episodic return=16.835186004638672
# global step=32768, episodic return=18.56991958618164
# global step=32768, episodic return=14.481836318969727
# global step=32768, episodic return=17.490633010864258
# global step=32768, episodic return=19.132015228271484
# global step=32768, episodic return=18.411767959594727
# global step=32768, episodic return=20.211515426635742
# global step=34816, episodic return=25.87560272216797
# global step=34816, episodic return=19.04814338684082
# global step=34816, episodic return=21.629114151000977
# global step=34816, episodic return=13.92196273803711
# global step=34816, episodic return=12.421060562133789
# global step=34816, episodic return=13.24576187133789
# global step=34816, episodic return=19.333154678344727
# global step=34816, episodic return=22.357515335083008
# global step=34816, episodic return=24.280181884765625
# global step=34816, episodic return=23.304529190063477
# global step=34816, episodic return=26.297273635864258
# global step=34816, episodic return=26.969322204589844
# global step=34816, episodic return=20.075904846191406
# global step=34816, episodic return=20.446613311767578
# global step=34816, episodic return=19.57477378845215
# global step=34816, episodic return=18.117637634277344
# global step=34816, episodic return=21.99646759033203
# global step=34816, episodic return=23.663644790649414
# global step=34816, episodic return=18.412973403930664
# global step=36864, episodic return=24.02237892150879
# global step=36864, episodic return=26.112693786621094
# global step=36864, episodic return=14.037555694580078
# global step=36864, episodic return=22.322660446166992
# global step=36864, episodic return=20.895774841308594
# global step=36864, episodic return=20.70577621459961
# global step=36864, episodic return=24.652536392211914
# global step=36864, episodic return=18.560190200805664
# global step=36864, episodic return=21.378643035888672
# global step=36864, episodic return=23.889053344726562
# global step=36864, episodic return=24.006610870361328
# global step=36864, episodic return=20.062833786010742
# global step=36864, episodic return=21.9189510345459
# global step=36864, episodic return=25.701095581054688
# global step=36864, episodic return=25.947847366333008
# global step=36864, episodic return=22.04297637939453
# global step=36864, episodic return=26.269489288330078
# global step=36864, episodic return=24.838665008544922
# global step=36864, episodic return=17.91897201538086
# global step=36864, episodic return=21.249069213867188
# global step=36864, episodic return=21.984111785888672
# global step=36864, episodic return=21.447439193725586
# global step=36864, episodic return=17.74444007873535
# global step=36864, episodic return=21.013713836669922
# global step=36864, episodic return=20.5842342376709
# global step=36864, episodic return=22.998414993286133
# global step=38912, episodic return=16.901626586914062
# global step=38912, episodic return=18.029678344726562
# global step=38912, episodic return=22.469999313354492
# global step=38912, episodic return=17.558740615844727
# global step=38912, episodic return=18.832275390625
# global step=38912, episodic return=16.955625534057617
# global step=38912, episodic return=17.100357055664062
# global step=38912, episodic return=16.665327072143555
# global step=38912, episodic return=18.874114990234375
# global step=38912, episodic return=26.155254364013672
# global step=38912, episodic return=20.181785583496094
# global step=38912, episodic return=27.70655059814453
# global step=38912, episodic return=21.94135093688965
# global step=38912, episodic return=24.369049072265625
# global step=38912, episodic return=16.87841033935547
# global step=38912, episodic return=27.324493408203125
# global step=38912, episodic return=24.136537551879883
# global step=38912, episodic return=24.922250747680664
# global step=38912, episodic return=22.76065444946289
# global step=38912, episodic return=22.786909103393555
# global step=38912, episodic return=23.129085540771484
# global step=38912, episodic return=22.835538864135742
# global step=38912, episodic return=18.869617462158203
# global step=38912, episodic return=22.35115623474121
# global step=38912, episodic return=23.975173950195312
# global step=38912, episodic return=18.86964225769043
# global step=38912, episodic return=18.58238410949707
# global step=38912, episodic return=16.854555130004883
# global step=38912, episodic return=24.153770446777344
# global step=38912, episodic return=20.332691192626953
# global step=38912, episodic return=19.13869285583496
# global step=38912, episodic return=31.51927375793457
# global step=38912, episodic return=18.220155715942383
# global step=38912, episodic return=20.155376434326172
# global step=38912, episodic return=25.096534729003906
# global step=40960, episodic return=29.44143295288086
# global step=40960, episodic return=22.85036277770996
# global step=40960, episodic return=22.269794464111328
# global step=40960, episodic return=21.310029983520508
# global step=40960, episodic return=26.8839111328125
# global step=40960, episodic return=15.400589942932129
# global step=40960, episodic return=22.678991317749023
# global step=40960, episodic return=17.242464065551758
# global step=40960, episodic return=16.009748458862305
# global step=40960, episodic return=23.751466751098633
# global step=40960, episodic return=18.20900535583496
# global step=40960, episodic return=20.49660301208496
# global step=40960, episodic return=19.7197265625
# global step=40960, episodic return=16.14852523803711
# global step=40960, episodic return=18.734193801879883
# global step=40960, episodic return=20.866329193115234
# global step=40960, episodic return=27.427270889282227
# global step=40960, episodic return=17.832420349121094
# global step=40960, episodic return=24.272443771362305
# global step=40960, episodic return=24.91766357421875
# global step=40960, episodic return=28.59063720703125
# global step=40960, episodic return=21.543895721435547
# global step=40960, episodic return=19.582365036010742
# global step=40960, episodic return=27.39799690246582
# global step=40960, episodic return=27.757381439208984
# global step=40960, episodic return=21.79651641845703
# global step=40960, episodic return=16.473175048828125
# global step=40960, episodic return=26.671844482421875
# global step=40960, episodic return=24.126449584960938
# global step=43008, episodic return=24.327346801757812
# global step=43008, episodic return=14.532404899597168
# global step=43008, episodic return=16.046833038330078
# global step=43008, episodic return=19.973392486572266
# global step=43008, episodic return=28.11031723022461
# global step=43008, episodic return=28.751754760742188
# global step=43008, episodic return=26.39724349975586
# global step=43008, episodic return=23.664262771606445
# global step=43008, episodic return=22.49559783935547
# global step=43008, episodic return=29.2636661529541
# global step=43008, episodic return=27.139434814453125
# global step=43008, episodic return=27.184921264648438
# global step=43008, episodic return=22.29599380493164
# global step=43008, episodic return=31.03013801574707
# global step=43008, episodic return=25.203838348388672
# global step=43008, episodic return=29.50861930847168
# global step=43008, episodic return=19.689224243164062
# global step=43008, episodic return=23.92926788330078
# global step=43008, episodic return=21.678667068481445
# global step=43008, episodic return=25.151287078857422
# global step=43008, episodic return=25.924821853637695
# global step=43008, episodic return=32.102874755859375
# global step=43008, episodic return=18.415117263793945
# global step=43008, episodic return=26.454118728637695
# global step=43008, episodic return=25.115806579589844
# global step=43008, episodic return=26.1585636138916
# global step=43008, episodic return=24.50143814086914
# global step=43008, episodic return=19.815677642822266
# global step=43008, episodic return=31.546875
# global step=43008, episodic return=27.999561309814453
# global step=43008, episodic return=26.855833053588867
# global step=43008, episodic return=20.850431442260742
# global step=43008, episodic return=16.13501739501953
# global step=43008, episodic return=19.199012756347656
# global step=43008, episodic return=26.642213821411133
# global step=43008, episodic return=18.695018768310547
# global step=43008, episodic return=23.15367889404297
# global step=43008, episodic return=23.241132736206055
# global step=43008, episodic return=24.35701560974121
# global step=45056, episodic return=21.39621353149414
# global step=45056, episodic return=19.31949234008789
# global step=45056, episodic return=19.18535804748535
# global step=45056, episodic return=22.118677139282227
# global step=45056, episodic return=28.002304077148438
# global step=45056, episodic return=23.671424865722656
# global step=45056, episodic return=30.77683448791504
# global step=45056, episodic return=20.57680320739746
# global step=45056, episodic return=22.631654739379883
# global step=45056, episodic return=30.255117416381836
# global step=45056, episodic return=28.7211971282959
# global step=45056, episodic return=28.573467254638672
# global step=45056, episodic return=22.94367790222168
# global step=45056, episodic return=20.397859573364258
# global step=45056, episodic return=19.323408126831055
# global step=45056, episodic return=29.68819808959961
# global step=45056, episodic return=21.069595336914062
# global step=45056, episodic return=24.866275787353516
# global step=45056, episodic return=19.225385665893555
# global step=45056, episodic return=28.643901824951172
# global step=45056, episodic return=19.834598541259766
# global step=45056, episodic return=21.213626861572266
# global step=45056, episodic return=23.54461669921875
# global step=45056, episodic return=21.7949161529541
# global step=47104, episodic return=35.37666320800781
# global step=47104, episodic return=29.583106994628906
# global step=47104, episodic return=25.663820266723633
# global step=47104, episodic return=33.09230422973633
# global step=47104, episodic return=18.571731567382812
# global step=47104, episodic return=23.47905731201172
# global step=47104, episodic return=19.516448974609375
# global step=47104, episodic return=24.087722778320312
# global step=47104, episodic return=38.26552200317383
# global step=47104, episodic return=20.63153076171875
# global step=47104, episodic return=32.230098724365234
# global step=47104, episodic return=26.57394790649414
# global step=47104, episodic return=13.727986335754395
# global step=47104, episodic return=38.32176208496094
# global step=47104, episodic return=30.781600952148438
# global step=47104, episodic return=26.726680755615234
# global step=47104, episodic return=29.57476234436035
# global step=47104, episodic return=22.293333053588867
# global step=47104, episodic return=19.5993595123291
# global step=47104, episodic return=37.01560974121094
# global step=47104, episodic return=22.557004928588867
# global step=49152, episodic return=32.28916931152344
# global step=49152, episodic return=32.62500762939453
# global step=49152, episodic return=24.77843475341797
# global step=49152, episodic return=21.59479331970215
# global step=49152, episodic return=21.464027404785156
# global step=49152, episodic return=21.434715270996094
# global step=49152, episodic return=28.524616241455078
# global step=49152, episodic return=32.79292678833008
# global step=49152, episodic return=25.31302833557129
# global step=49152, episodic return=38.86488342285156
# global step=49152, episodic return=26.139894485473633
# global step=49152, episodic return=23.894498825073242
# global step=49152, episodic return=30.076833724975586
# global step=49152, episodic return=20.808130264282227
# global step=49152, episodic return=28.15310287475586
# global step=49152, episodic return=18.658756256103516
# global step=49152, episodic return=25.437911987304688
# global step=49152, episodic return=17.575931549072266
# global step=49152, episodic return=18.230314254760742
# global step=49152, episodic return=37.6193733215332
# global step=49152, episodic return=37.36781311035156
# global step=49152, episodic return=28.079442977905273
# global step=49152, episodic return=31.177688598632812
# global step=49152, episodic return=24.57754898071289
# global step=49152, episodic return=25.908946990966797
# global step=49152, episodic return=26.510208129882812
# global step=49152, episodic return=37.29076385498047
# global step=49152, episodic return=28.81033706665039
# global step=49152, episodic return=30.797971725463867
# global step=49152, episodic return=19.7385196685791
# global step=49152, episodic return=33.02069091796875
# global step=51200, episodic return=34.233768463134766
# global step=51200, episodic return=34.327884674072266
# global step=51200, episodic return=22.22786521911621
# global step=51200, episodic return=20.382427215576172
# global step=51200, episodic return=29.683446884155273
# global step=51200, episodic return=26.951404571533203
# global step=51200, episodic return=25.177112579345703
# global step=51200, episodic return=28.710180282592773
# global step=51200, episodic return=25.94574737548828
# global step=51200, episodic return=22.410221099853516
# global step=51200, episodic return=23.536680221557617
# global step=51200, episodic return=22.784101486206055
# global step=51200, episodic return=40.40169906616211
# global step=51200, episodic return=23.232173919677734
# global step=51200, episodic return=19.43842315673828
# global step=51200, episodic return=26.225807189941406
# global step=51200, episodic return=34.609153747558594
# global step=51200, episodic return=28.252580642700195
# global step=51200, episodic return=17.72263526916504
# global step=51200, episodic return=17.76758575439453
# global step=51200, episodic return=35.507911682128906
# global step=51200, episodic return=34.95777130126953
# global step=51200, episodic return=31.49344825744629
# global step=51200, episodic return=29.371837615966797
# global step=51200, episodic return=25.595741271972656
# global step=51200, episodic return=15.003847122192383
# global step=51200, episodic return=28.846925735473633
# global step=51200, episodic return=26.56721305847168
# global step=51200, episodic return=35.25654602050781
# global step=51200, episodic return=20.328907012939453
# global step=51200, episodic return=31.2471981048584
# global step=51200, episodic return=22.085412979125977
# global step=51200, episodic return=19.380184173583984
# global step=51200, episodic return=31.531673431396484
# global step=51200, episodic return=26.024341583251953
# global step=51200, episodic return=36.54625701904297
# global step=51200, episodic return=43.183895111083984
# global step=53248, episodic return=22.94548797607422
# global step=53248, episodic return=30.595745086669922
# global step=53248, episodic return=29.04290771484375
# global step=53248, episodic return=35.99015808105469
# global step=53248, episodic return=21.86359405517578
# global step=53248, episodic return=26.466392517089844
# global step=53248, episodic return=37.783958435058594
# global step=53248, episodic return=35.12251281738281
# global step=53248, episodic return=28.663084030151367
# global step=53248, episodic return=36.08131790161133
# global step=53248, episodic return=27.514923095703125
# global step=53248, episodic return=25.356111526489258
# global step=53248, episodic return=26.98796272277832
# global step=53248, episodic return=28.098703384399414
# global step=53248, episodic return=38.16562271118164
# global step=53248, episodic return=32.99797058105469
# global step=53248, episodic return=30.597684860229492
# global step=53248, episodic return=40.01618194580078
# global step=53248, episodic return=31.919689178466797
# global step=53248, episodic return=13.970605850219727
# global step=53248, episodic return=22.279098510742188
# global step=53248, episodic return=26.793447494506836
# global step=53248, episodic return=34.29630661010742
# global step=53248, episodic return=40.65837478637695
# global step=53248, episodic return=29.777572631835938
# global step=53248, episodic return=28.620298385620117
# global step=53248, episodic return=28.4086971282959
# global step=53248, episodic return=34.92436599731445
# global step=53248, episodic return=22.50693130493164
# global step=53248, episodic return=27.404560089111328
# global step=53248, episodic return=27.66326904296875
# global step=53248, episodic return=32.51698303222656
# global step=55296, episodic return=23.871004104614258
# global step=55296, episodic return=33.20840072631836
# global step=55296, episodic return=31.47034454345703
# global step=55296, episodic return=27.113277435302734
# global step=55296, episodic return=39.15043258666992
# global step=55296, episodic return=27.948762893676758
# global step=55296, episodic return=28.176427841186523
# global step=55296, episodic return=24.586273193359375
# global step=55296, episodic return=35.15778732299805
# global step=55296, episodic return=31.234905242919922
# global step=55296, episodic return=39.448997497558594
# global step=55296, episodic return=28.70009994506836
# global step=55296, episodic return=49.54293441772461
# global step=55296, episodic return=26.69116973876953
# global step=55296, episodic return=44.234413146972656
# global step=55296, episodic return=22.246788024902344
# global step=55296, episodic return=29.684894561767578
# global step=55296, episodic return=33.85131072998047
# global step=55296, episodic return=22.407136917114258
# global step=55296, episodic return=23.09018325805664
# global step=55296, episodic return=27.913572311401367
# global step=55296, episodic return=25.498546600341797
# global step=55296, episodic return=30.912338256835938
# global step=55296, episodic return=23.602130889892578
# global step=55296, episodic return=40.87114334106445
# global step=55296, episodic return=31.910900115966797
# global step=55296, episodic return=32.63645935058594
# global step=55296, episodic return=34.803504943847656
# global step=55296, episodic return=35.736183166503906
# global step=57344, episodic return=45.255985260009766
# global step=57344, episodic return=26.731483459472656
# global step=57344, episodic return=40.30890655517578
# global step=57344, episodic return=26.99468231201172
# global step=57344, episodic return=25.708534240722656
# global step=57344, episodic return=24.188661575317383
# global step=57344, episodic return=52.35895538330078
# global step=57344, episodic return=25.150981903076172
# global step=57344, episodic return=26.387657165527344
# global step=57344, episodic return=23.548133850097656
# global step=57344, episodic return=30.568374633789062
# global step=57344, episodic return=23.987987518310547
# global step=57344, episodic return=34.219295501708984
# global step=57344, episodic return=31.61086654663086
# global step=57344, episodic return=35.75211715698242
# global step=57344, episodic return=40.9789924621582
# global step=57344, episodic return=43.68452835083008
# global step=57344, episodic return=33.62297439575195
# global step=57344, episodic return=28.11422348022461
# global step=57344, episodic return=26.492467880249023
# global step=57344, episodic return=43.004940032958984
# global step=57344, episodic return=35.224464416503906
# global step=57344, episodic return=22.845111846923828
# global step=57344, episodic return=28.8501033782959
# global step=57344, episodic return=23.08473777770996
# global step=59392, episodic return=29.412588119506836
# global step=59392, episodic return=24.902385711669922
# global step=59392, episodic return=19.19925880432129
# global step=59392, episodic return=38.311458587646484
# global step=59392, episodic return=34.925697326660156
# global step=59392, episodic return=36.096641540527344
# global step=59392, episodic return=21.987363815307617
# global step=59392, episodic return=41.91154098510742
# global step=59392, episodic return=27.103954315185547
# global step=59392, episodic return=36.772186279296875
# global step=59392, episodic return=30.560163497924805
# global step=59392, episodic return=28.844886779785156
# global step=59392, episodic return=39.77180480957031
# global step=59392, episodic return=37.58757400512695
# global step=59392, episodic return=29.547212600708008
# global step=59392, episodic return=21.95220184326172
# global step=59392, episodic return=17.52252197265625
# global step=59392, episodic return=30.079933166503906
# global step=59392, episodic return=34.626556396484375
# global step=59392, episodic return=34.3998908996582
# global step=59392, episodic return=35.616302490234375
# global step=59392, episodic return=29.11307144165039
# global step=59392, episodic return=19.919937133789062
# global step=59392, episodic return=21.892650604248047
# global step=59392, episodic return=40.76261901855469
# global step=59392, episodic return=45.42133331298828
# global step=59392, episodic return=35.32448196411133
# global step=59392, episodic return=35.79023361206055
# global step=59392, episodic return=27.575237274169922
# global step=61440, episodic return=32.47040939331055
# global step=61440, episodic return=17.6245059967041
# global step=61440, episodic return=28.018903732299805
# global step=61440, episodic return=36.18178939819336
# global step=61440, episodic return=23.646587371826172
# global step=61440, episodic return=36.11131286621094
# global step=61440, episodic return=47.77275466918945
# global step=61440, episodic return=27.060029983520508
# global step=61440, episodic return=41.7083740234375
# global step=61440, episodic return=10.534317016601562
# global step=61440, episodic return=30.811601638793945
# global step=61440, episodic return=43.396270751953125
# global step=61440, episodic return=32.520179748535156
# global step=61440, episodic return=33.429351806640625
# global step=61440, episodic return=36.716888427734375
# global step=61440, episodic return=31.00149917602539
# global step=61440, episodic return=42.81370544433594
# global step=61440, episodic return=43.64211654663086
# global step=61440, episodic return=29.24125099182129
# global step=61440, episodic return=25.251211166381836
# global step=61440, episodic return=44.03123474121094
# global step=61440, episodic return=30.787179946899414
# global step=61440, episodic return=20.79152488708496
# global step=61440, episodic return=34.832359313964844
# global step=61440, episodic return=24.45598030090332
# global step=63488, episodic return=48.962493896484375
# global step=63488, episodic return=23.798561096191406
# global step=63488, episodic return=30.31987190246582
# global step=63488, episodic return=27.046234130859375
# global step=63488, episodic return=40.099891662597656
# global step=63488, episodic return=42.141605377197266
# global step=63488, episodic return=28.523611068725586
# global step=63488, episodic return=41.29011154174805
# global step=63488, episodic return=40.11479568481445
# global step=63488, episodic return=37.224578857421875
# global step=63488, episodic return=28.711763381958008
# global step=63488, episodic return=33.1423454284668
# global step=63488, episodic return=48.33235168457031
# global step=63488, episodic return=21.15937042236328
# global step=63488, episodic return=38.02764129638672
# global step=63488, episodic return=31.717145919799805
# global step=63488, episodic return=37.34270095825195
# global step=63488, episodic return=35.22083282470703
# global step=63488, episodic return=32.527183532714844
# global step=63488, episodic return=30.332244873046875
# global step=63488, episodic return=21.72977066040039
# global step=63488, episodic return=45.0418586730957
# global step=63488, episodic return=32.567909240722656
# global step=63488, episodic return=32.850746154785156
# global step=63488, episodic return=26.360483169555664
# global step=63488, episodic return=31.610883712768555
# global step=63488, episodic return=31.398014068603516
# global step=63488, episodic return=34.19902801513672
# global step=63488, episodic return=32.605796813964844
# global step=63488, episodic return=41.08504867553711
# global step=63488, episodic return=40.35890579223633
# global step=63488, episodic return=30.95716667175293
# global step=63488, episodic return=24.424806594848633
# global step=63488, episodic return=43.22221374511719
# global step=63488, episodic return=28.892757415771484
# global step=65536, episodic return=27.63336753845215
# global step=65536, episodic return=34.29399490356445
# global step=65536, episodic return=49.295433044433594
# global step=65536, episodic return=34.66822814941406
# global step=65536, episodic return=26.692352294921875
# global step=65536, episodic return=32.58361053466797
# global step=65536, episodic return=40.302791595458984
# global step=65536, episodic return=41.352821350097656
# global step=65536, episodic return=29.759113311767578
# global step=65536, episodic return=34.444889068603516
# global step=65536, episodic return=26.41341209411621
# global step=65536, episodic return=40.94466781616211
# global step=65536, episodic return=36.154258728027344
# global step=65536, episodic return=27.138940811157227
# global step=65536, episodic return=42.13890838623047
# global step=65536, episodic return=18.20254898071289
# global step=65536, episodic return=42.699859619140625
# global step=65536, episodic return=39.585784912109375
# global step=65536, episodic return=46.674217224121094
# global step=65536, episodic return=34.76983642578125
# global step=65536, episodic return=27.603178024291992
# global step=65536, episodic return=29.18067169189453
# global step=65536, episodic return=26.007936477661133
# global step=65536, episodic return=19.81462860107422
# global step=65536, episodic return=42.44940185546875
# global step=65536, episodic return=47.039146423339844
# global step=65536, episodic return=40.902061462402344
# global step=65536, episodic return=32.63184356689453
# global step=65536, episodic return=32.9696159362793
# global step=65536, episodic return=43.07221984863281
# global step=65536, episodic return=40.54305648803711
# global step=65536, episodic return=47.846736907958984
# global step=67584, episodic return=35.867286682128906
# global step=67584, episodic return=39.145687103271484
# global step=67584, episodic return=15.819113731384277
# global step=67584, episodic return=26.862579345703125
# global step=67584, episodic return=34.254234313964844
# global step=67584, episodic return=34.1224365234375
# global step=67584, episodic return=40.940425872802734
# global step=67584, episodic return=24.79446792602539
# global step=67584, episodic return=38.271114349365234
# global step=67584, episodic return=43.275386810302734
# global step=67584, episodic return=32.533016204833984
# global step=67584, episodic return=28.433727264404297
# global step=67584, episodic return=41.60028839111328
# global step=67584, episodic return=45.74600601196289
# global step=67584, episodic return=41.87513732910156
# global step=67584, episodic return=25.547109603881836
# global step=67584, episodic return=54.3702278137207
# global step=67584, episodic return=29.08980941772461
# global step=67584, episodic return=24.453596115112305
# global step=67584, episodic return=49.92037582397461
# global step=67584, episodic return=39.231658935546875
# global step=67584, episodic return=22.664112091064453
# global step=69632, episodic return=44.118370056152344
# global step=69632, episodic return=33.456764221191406
# global step=69632, episodic return=24.000608444213867
# global step=69632, episodic return=37.29793167114258
# global step=69632, episodic return=31.000747680664062
# global step=69632, episodic return=30.652576446533203
# global step=69632, episodic return=33.55405807495117
# global step=69632, episodic return=34.786903381347656
# global step=69632, episodic return=34.90351104736328
# global step=69632, episodic return=45.41026306152344
# global step=69632, episodic return=36.3646240234375
# global step=69632, episodic return=45.95629119873047
# global step=69632, episodic return=53.904903411865234
# global step=69632, episodic return=53.64837646484375
# global step=69632, episodic return=33.987205505371094
# global step=69632, episodic return=25.97808265686035
# global step=69632, episodic return=40.04533386230469
# global step=69632, episodic return=48.835323333740234
# global step=69632, episodic return=38.48177719116211
# global step=69632, episodic return=45.53923416137695
# global step=69632, episodic return=47.16401290893555
# global step=69632, episodic return=30.998260498046875
# global step=71680, episodic return=41.243011474609375
# global step=71680, episodic return=31.78999137878418
# global step=71680, episodic return=36.6878776550293
# global step=71680, episodic return=40.301658630371094
# global step=71680, episodic return=26.83642578125
# global step=71680, episodic return=51.95746612548828
# global step=71680, episodic return=28.449993133544922
# global step=71680, episodic return=40.14786148071289
# global step=71680, episodic return=51.00023651123047
# global step=71680, episodic return=42.30906677246094
# global step=71680, episodic return=40.23825454711914
# global step=71680, episodic return=39.1786994934082
# global step=71680, episodic return=25.431026458740234
# global step=71680, episodic return=41.403900146484375
# global step=71680, episodic return=43.8036003112793
# global step=71680, episodic return=48.69121551513672
# global step=71680, episodic return=31.560455322265625
# global step=71680, episodic return=27.88109588623047
# global step=71680, episodic return=30.164323806762695
# global step=71680, episodic return=50.473670959472656
# global step=71680, episodic return=22.953201293945312
# global step=71680, episodic return=31.251686096191406
# global step=71680, episodic return=35.75760269165039
# global step=71680, episodic return=39.292964935302734
# global step=71680, episodic return=34.434326171875
# global step=71680, episodic return=31.052337646484375
# global step=71680, episodic return=49.15288162231445
# global step=71680, episodic return=39.63996505737305
# global step=71680, episodic return=42.59297180175781
# global step=73728, episodic return=47.45670700073242
# global step=73728, episodic return=21.721445083618164
# global step=73728, episodic return=41.196128845214844
# global step=73728, episodic return=23.94297981262207
# global step=73728, episodic return=42.45405960083008
# global step=73728, episodic return=35.980525970458984
# global step=73728, episodic return=29.656890869140625
# global step=73728, episodic return=49.48625564575195
# global step=73728, episodic return=44.12056350708008
# global step=73728, episodic return=30.90233612060547
# global step=73728, episodic return=30.51262664794922
# global step=73728, episodic return=32.49525451660156
# global step=73728, episodic return=51.1160774230957
# global step=73728, episodic return=45.87120056152344
# global step=73728, episodic return=40.76134490966797
# global step=73728, episodic return=37.88818359375
# global step=73728, episodic return=33.99202346801758
# global step=73728, episodic return=28.136545181274414
# global step=73728, episodic return=30.358190536499023
# global step=73728, episodic return=44.59384536743164
# global step=73728, episodic return=38.31287384033203
# global step=73728, episodic return=27.58403205871582
# global step=73728, episodic return=52.6279182434082
# global step=73728, episodic return=36.103919982910156
# global step=73728, episodic return=25.57388687133789
# global step=75776, episodic return=43.16426467895508
# global step=75776, episodic return=16.57837677001953
# global step=75776, episodic return=14.710445404052734
# global step=75776, episodic return=45.80632400512695
# global step=75776, episodic return=33.44219207763672
# global step=75776, episodic return=31.253284454345703
# global step=75776, episodic return=27.068737030029297
# global step=75776, episodic return=42.23481369018555
# global step=75776, episodic return=38.360801696777344
# global step=75776, episodic return=38.951229095458984
# global step=75776, episodic return=24.63180923461914
# global step=75776, episodic return=30.707603454589844
# global step=75776, episodic return=38.31546401977539
# global step=75776, episodic return=41.3112907409668
# global step=75776, episodic return=33.863059997558594
# global step=75776, episodic return=43.87250518798828
# global step=75776, episodic return=45.07146072387695
# global step=75776, episodic return=54.93770980834961
# global step=75776, episodic return=59.57693099975586
# global step=75776, episodic return=25.156993865966797
# global step=75776, episodic return=34.443233489990234
# global step=75776, episodic return=27.572612762451172
# global step=75776, episodic return=27.86257553100586
# global step=75776, episodic return=31.617244720458984
# global step=75776, episodic return=56.55775451660156
# global step=77824, episodic return=38.02887725830078
# global step=77824, episodic return=38.085899353027344
# global step=77824, episodic return=39.18760299682617
# global step=77824, episodic return=39.47301483154297
# global step=77824, episodic return=46.77017593383789
# global step=77824, episodic return=36.698936462402344
# global step=77824, episodic return=33.681495666503906
# global step=77824, episodic return=48.56209945678711
# global step=77824, episodic return=33.126094818115234
# global step=77824, episodic return=28.493974685668945
# global step=77824, episodic return=44.4841423034668
# global step=77824, episodic return=47.32398223876953
# global step=77824, episodic return=40.989376068115234
# global step=77824, episodic return=53.12196350097656
# global step=77824, episodic return=42.07720184326172
# global step=77824, episodic return=56.59679412841797
# global step=77824, episodic return=20.590171813964844
# global step=77824, episodic return=35.936058044433594
# global step=79872, episodic return=55.94248962402344
# global step=79872, episodic return=26.903955459594727
# global step=79872, episodic return=31.145299911499023
# global step=79872, episodic return=30.322956085205078
# global step=79872, episodic return=26.1756649017334
# global step=79872, episodic return=57.36513137817383
# global step=79872, episodic return=42.58430862426758
# global step=79872, episodic return=54.327457427978516
# global step=79872, episodic return=39.84551239013672
# global step=79872, episodic return=31.671127319335938
# global step=79872, episodic return=42.851173400878906
# global step=79872, episodic return=52.525550842285156
# global step=79872, episodic return=47.159095764160156
# global step=79872, episodic return=41.08034133911133
# global step=79872, episodic return=57.26686477661133
# global step=79872, episodic return=39.490787506103516
# global step=79872, episodic return=19.923294067382812
# global step=79872, episodic return=47.80299377441406
# global step=79872, episodic return=26.77962303161621
# global step=81920, episodic return=44.636329650878906
# global step=81920, episodic return=48.3856201171875
# global step=81920, episodic return=45.91082763671875
# global step=81920, episodic return=37.279197692871094
# global step=81920, episodic return=38.653289794921875
# global step=81920, episodic return=29.42557716369629
# global step=81920, episodic return=45.365623474121094
# global step=81920, episodic return=37.68520736694336
# global step=81920, episodic return=44.04645919799805
# global step=81920, episodic return=51.131282806396484
# global step=81920, episodic return=37.44150161743164
# global step=81920, episodic return=42.359580993652344
# global step=81920, episodic return=38.679039001464844
# global step=81920, episodic return=34.279823303222656
# global step=81920, episodic return=42.68213653564453
# global step=81920, episodic return=32.6516227722168
# global step=83968, episodic return=47.24539566040039
# global step=83968, episodic return=63.37600326538086
# global step=83968, episodic return=35.02423095703125
# global step=83968, episodic return=62.66966247558594
# global step=83968, episodic return=52.53535079956055
# global step=83968, episodic return=47.71731185913086
# global step=83968, episodic return=26.85332489013672
# global step=83968, episodic return=50.104522705078125
# global step=83968, episodic return=25.162124633789062
# global step=83968, episodic return=45.578399658203125
# global step=83968, episodic return=67.37852478027344
# global step=83968, episodic return=32.13127136230469
# global step=83968, episodic return=31.619728088378906
# global step=86016, episodic return=41.70166778564453
# global step=86016, episodic return=45.547080993652344
# global step=86016, episodic return=46.44737243652344
# global step=86016, episodic return=36.149105072021484
# global step=86016, episodic return=41.10102081298828
# global step=86016, episodic return=47.640228271484375
# global step=86016, episodic return=26.66370964050293
# global step=86016, episodic return=38.774375915527344
# global step=86016, episodic return=50.21406555175781
# global step=86016, episodic return=33.98784255981445
# global step=86016, episodic return=37.985504150390625
# global step=86016, episodic return=33.21811294555664
# global step=86016, episodic return=54.97761917114258
# global step=86016, episodic return=36.13933181762695
# global step=86016, episodic return=32.9420166015625
# global step=86016, episodic return=60.14530563354492
# global step=86016, episodic return=28.325180053710938
# global step=86016, episodic return=20.093656539916992
# global step=86016, episodic return=36.60011291503906
# global step=88064, episodic return=42.26201629638672
# global step=88064, episodic return=36.65878677368164
# global step=88064, episodic return=31.35564422607422
# global step=88064, episodic return=35.8906364440918
# global step=88064, episodic return=66.32967376708984
# global step=88064, episodic return=42.697776794433594
# global step=88064, episodic return=19.550209045410156
# global step=88064, episodic return=53.792076110839844
# global step=88064, episodic return=37.3743782043457
# global step=88064, episodic return=50.58866500854492
# global step=88064, episodic return=65.44536590576172
# global step=90112, episodic return=35.55979537963867
# global step=90112, episodic return=34.97687911987305
# global step=90112, episodic return=36.72806930541992
# global step=90112, episodic return=34.12173843383789
# global step=90112, episodic return=30.98308563232422
# global step=90112, episodic return=48.413429260253906
# global step=92160, episodic return=45.529056549072266
# global step=92160, episodic return=57.66811752319336
# global step=92160, episodic return=56.13434600830078
# global step=92160, episodic return=53.80650329589844
# global step=92160, episodic return=47.077449798583984
# global step=92160, episodic return=45.313053131103516
# global step=92160, episodic return=45.03179168701172
# global step=92160, episodic return=53.505775451660156
# global step=92160, episodic return=31.97002601623535
# global step=92160, episodic return=26.37390899658203
# global step=94208, episodic return=48.53145217895508
# global step=94208, episodic return=49.17601013183594
# global step=94208, episodic return=19.3236083984375
# global step=94208, episodic return=40.097801208496094
# global step=94208, episodic return=35.165855407714844
# global step=94208, episodic return=59.4278564453125
# global step=94208, episodic return=27.56252670288086
# global step=94208, episodic return=56.83833312988281
# global step=94208, episodic return=44.407630920410156
# global step=94208, episodic return=39.54468536376953
# global step=96256, episodic return=33.139617919921875
# global step=96256, episodic return=45.65312194824219
# global step=96256, episodic return=54.66670227050781
# global step=96256, episodic return=31.10284996032715
# global step=96256, episodic return=74.49034881591797
# global step=96256, episodic return=57.419490814208984
# global step=96256, episodic return=46.93799591064453
# global step=96256, episodic return=41.67231750488281
# global step=96256, episodic return=53.91381072998047
# global step=98304, episodic return=78.99368286132812
# global step=98304, episodic return=21.679147720336914
# global step=98304, episodic return=34.435028076171875
# global step=98304, episodic return=23.583477020263672
# global step=98304, episodic return=46.16166687011719
# global step=98304, episodic return=66.40638732910156
# global step=98304, episodic return=25.73748779296875
# global step=98304, episodic return=43.46160888671875
# global step=98304, episodic return=52.05854415893555
# global step=100352, episodic return=78.16674041748047
# global step=100352, episodic return=22.810041427612305
# global step=100352, episodic return=58.348358154296875
# global step=100352, episodic return=41.6849365234375
# global step=100352, episodic return=27.03006362915039
# global step=100352, episodic return=38.81620788574219
# global step=100352, episodic return=20.570636749267578
# global step=100352, episodic return=53.43601989746094
# global step=100352, episodic return=54.628318786621094
# global step=100352, episodic return=44.43791198730469
# global step=100352, episodic return=34.449989318847656
# global step=100352, episodic return=59.89144515991211
# global step=100352, episodic return=29.112308502197266
# global step=100352, episodic return=42.89854431152344
# global step=100352, episodic return=23.891206741333008
# global step=100352, episodic return=29.417600631713867
# global step=100352, episodic return=60.45159149169922
# global step=102400, episodic return=14.426070213317871
# global step=102400, episodic return=57.77436828613281
# global step=102400, episodic return=33.69483947753906
# global step=102400, episodic return=36.95338439941406
# global step=102400, episodic return=53.8869514465332
# global step=102400, episodic return=25.286636352539062
# global step=102400, episodic return=39.34611892700195
# global step=102400, episodic return=45.473453521728516
# global step=102400, episodic return=33.41410446166992
# global step=102400, episodic return=61.69172286987305
# global step=102400, episodic return=79.41494750976562
# global step=102400, episodic return=29.665979385375977
# global step=102400, episodic return=41.57038879394531
# global step=102400, episodic return=45.47995376586914
# global step=102400, episodic return=73.48834991455078
# global step=102400, episodic return=57.04984664916992
# global step=102400, episodic return=71.03136444091797
# global step=102400, episodic return=63.0537223815918
# global step=102400, episodic return=43.642826080322266
# global step=102400, episodic return=31.186235427856445
# global step=102400, episodic return=35.386470794677734
# global step=102400, episodic return=41.12507629394531
# global step=104448, episodic return=39.21761703491211
# global step=104448, episodic return=61.55723571777344
# global step=104448, episodic return=52.302757263183594
# global step=104448, episodic return=64.39154052734375
# global step=104448, episodic return=29.71919822692871
# global step=104448, episodic return=34.16132736206055
# global step=104448, episodic return=30.36929702758789
# global step=104448, episodic return=32.19138717651367
# global step=104448, episodic return=58.45585250854492
# global step=104448, episodic return=51.58891296386719
# global step=104448, episodic return=44.83625030517578
# global step=104448, episodic return=31.566377639770508
# global step=104448, episodic return=35.56046676635742
# global step=104448, episodic return=31.70126724243164
# global step=104448, episodic return=32.41500473022461
# global step=106496, episodic return=45.54326248168945
# global step=106496, episodic return=36.61048889160156
# global step=106496, episodic return=28.88582420349121
# global step=106496, episodic return=49.07225799560547
# global step=106496, episodic return=86.06153869628906
# global step=106496, episodic return=49.257896423339844
# global step=106496, episodic return=79.96820831298828
# global step=106496, episodic return=23.1292724609375
# global step=106496, episodic return=59.343257904052734
# global step=106496, episodic return=33.20661163330078
# global step=106496, episodic return=47.7531852722168
# global step=108544, episodic return=63.05913162231445
# global step=108544, episodic return=54.6556510925293
# global step=108544, episodic return=53.724544525146484
# global step=108544, episodic return=62.633480072021484
# global step=108544, episodic return=65.41255950927734
# global step=108544, episodic return=43.157108306884766
# global step=108544, episodic return=85.61802673339844
# global step=108544, episodic return=49.11207580566406
# global step=110592, episodic return=43.408748626708984
# global step=110592, episodic return=46.825443267822266
# global step=110592, episodic return=54.25971603393555
# global step=110592, episodic return=57.32415008544922
# global step=110592, episodic return=53.39119338989258
# global step=110592, episodic return=62.37877655029297
# global step=110592, episodic return=54.044193267822266
# global step=110592, episodic return=49.09524154663086
# global step=110592, episodic return=66.27922058105469
# global step=110592, episodic return=46.35047912597656
# global step=110592, episodic return=80.4158706665039
# global step=110592, episodic return=48.473270416259766
# global step=112640, episodic return=59.144142150878906
# global step=112640, episodic return=49.64802169799805
# global step=112640, episodic return=61.15755844116211
# global step=112640, episodic return=63.591819763183594
# global step=112640, episodic return=36.683326721191406
# global step=112640, episodic return=53.23719787597656
# global step=112640, episodic return=55.45504379272461
# global step=114688, episodic return=45.81066131591797
# global step=114688, episodic return=29.23475456237793
# global step=114688, episodic return=39.485252380371094
# global step=114688, episodic return=59.4788703918457
# global step=114688, episodic return=57.97498321533203
# global step=114688, episodic return=46.90884017944336
# global step=114688, episodic return=46.831790924072266
# global step=114688, episodic return=42.22270965576172
# global step=116736, episodic return=32.075523376464844
# global step=116736, episodic return=40.30857849121094
# global step=116736, episodic return=32.325687408447266
# global step=116736, episodic return=33.72013473510742
# global step=116736, episodic return=83.23788452148438
# global step=116736, episodic return=72.20948028564453
# global step=116736, episodic return=47.66031265258789
# global step=116736, episodic return=44.89789581298828
# global step=116736, episodic return=33.72868728637695
# global step=116736, episodic return=50.22785949707031
# global step=116736, episodic return=67.91123962402344
# global step=118784, episodic return=48.061744689941406
# global step=118784, episodic return=63.86985778808594
# global step=118784, episodic return=12.156582832336426
# global step=118784, episodic return=35.16755676269531
# global step=118784, episodic return=60.18828582763672
# global step=118784, episodic return=42.511043548583984
# global step=118784, episodic return=31.49481201171875
# global step=118784, episodic return=56.20630645751953
# global step=118784, episodic return=22.53460693359375
# global step=118784, episodic return=65.3449935913086
# global step=118784, episodic return=40.68278121948242
# global step=120832, episodic return=43.6191520690918
# global step=120832, episodic return=68.2335205078125
# global step=120832, episodic return=42.1335334777832
# global step=120832, episodic return=82.03536224365234
# global step=120832, episodic return=67.35926055908203
# global step=120832, episodic return=73.68391418457031
# global step=120832, episodic return=24.71375846862793
# global step=120832, episodic return=50.50570297241211
# global step=120832, episodic return=68.37516021728516
# global step=120832, episodic return=69.46082305908203
# global step=120832, episodic return=45.79322052001953
# global step=120832, episodic return=88.49371337890625
# global step=120832, episodic return=41.21945571899414
# global step=120832, episodic return=23.307674407958984
# global step=122880, episodic return=37.96257400512695
# global step=122880, episodic return=97.46634674072266
# global step=122880, episodic return=23.152706146240234
# global step=122880, episodic return=45.02001953125
# global step=122880, episodic return=85.51907348632812
# global step=122880, episodic return=56.863037109375
# global step=124928, episodic return=70.2880630493164
# global step=124928, episodic return=34.03626251220703
# global step=124928, episodic return=34.09438705444336
# global step=124928, episodic return=40.998104095458984
# global step=124928, episodic return=54.26404571533203
# global step=124928, episodic return=36.338863372802734
# global step=124928, episodic return=24.98666763305664
# global step=124928, episodic return=46.736934661865234
# global step=124928, episodic return=41.66084289550781
# global step=126976, episodic return=53.21379089355469
# global step=126976, episodic return=37.773929595947266
# global step=126976, episodic return=29.343172073364258
# global step=126976, episodic return=52.69856262207031
# global step=126976, episodic return=51.92339324951172
# global step=129024, episodic return=73.632080078125
# global step=129024, episodic return=42.70926284790039
# global step=129024, episodic return=92.47269439697266
# global step=129024, episodic return=58.9207878112793
# global step=129024, episodic return=40.48356246948242
# global step=129024, episodic return=71.69153594970703
# global step=131072, episodic return=56.18304443359375
# global step=131072, episodic return=101.68414306640625
# global step=131072, episodic return=77.12566375732422
# global step=131072, episodic return=91.77432250976562
# global step=131072, episodic return=32.09180450439453
# global step=131072, episodic return=30.414548873901367
# global step=133120, episodic return=69.2389144897461
# global step=133120, episodic return=42.666786193847656
# global step=133120, episodic return=74.64335632324219
# global step=135168, episodic return=97.85387420654297
# global step=135168, episodic return=49.46849822998047
# global step=137216, episodic return=54.026039123535156
# global step=137216, episodic return=35.21200180053711
# global step=137216, episodic return=72.25829315185547
# global step=137216, episodic return=47.63777542114258
# global step=137216, episodic return=34.035682678222656
# global step=137216, episodic return=63.99352264404297
# global step=137216, episodic return=76.03528594970703
# global step=137216, episodic return=105.10678100585938
# global step=137216, episodic return=55.929351806640625
# global step=139264, episodic return=39.673072814941406
# global step=139264, episodic return=79.22863006591797
# global step=139264, episodic return=86.74337005615234
# global step=139264, episodic return=49.00348663330078
# global step=139264, episodic return=97.1708984375
# global step=139264, episodic return=36.10669708251953
# global step=139264, episodic return=52.49822998046875
# global step=139264, episodic return=76.25595092773438
# global step=141312, episodic return=61.48731994628906
# global step=141312, episodic return=56.68489074707031
# global step=141312, episodic return=78.22904205322266
# global step=141312, episodic return=23.802331924438477
# global step=141312, episodic return=46.14147186279297
# global step=143360, episodic return=102.68688201904297
# global step=143360, episodic return=106.37104797363281
# global step=143360, episodic return=55.93718338012695
# global step=143360, episodic return=66.42958068847656
# global step=143360, episodic return=52.379188537597656
# global step=143360, episodic return=52.70034408569336
# global step=143360, episodic return=35.36477279663086
# global step=145408, episodic return=55.640419006347656
# global step=145408, episodic return=107.2426528930664
# global step=145408, episodic return=40.168575286865234
# global step=145408, episodic return=50.109703063964844
# global step=147456, episodic return=30.589887619018555
# global step=147456, episodic return=50.261802673339844
# global step=147456, episodic return=50.501853942871094
# global step=147456, episodic return=94.9032211303711
# global step=147456, episodic return=66.40283966064453
# global step=147456, episodic return=51.17117691040039
# global step=147456, episodic return=114.13872528076172
# global step=149504, episodic return=78.728271484375
# global step=149504, episodic return=48.19704055786133
# global step=151552, episodic return=83.24935913085938
# global step=153600, episodic return=60.150264739990234
# global step=155648, episodic return=35.56370162963867
# global step=157696, episodic return=49.265541076660156
# global step=157696, episodic return=44.016868591308594
# global step=157696, episodic return=84.02886962890625
# global step=159744, episodic return=78.26170349121094
# global step=159744, episodic return=36.187801361083984
# global step=161792, episodic return=50.370765686035156
# global step=161792, episodic return=63.262367248535156
# global step=161792, episodic return=96.28340911865234
# global step=161792, episodic return=60.09465408325195
# global step=161792, episodic return=99.65935516357422
# global step=163840, episodic return=42.275447845458984
# global step=163840, episodic return=63.586273193359375
# global step=163840, episodic return=41.63545608520508
# global step=165888, episodic return=73.25444793701172
# global step=165888, episodic return=65.04924011230469
# global step=165888, episodic return=111.55181884765625
# global step=165888, episodic return=95.14501190185547
# global step=167936, episodic return=49.36885452270508
# global step=167936, episodic return=81.65157318115234
# global step=167936, episodic return=30.61746597290039
# global step=172032, episodic return=54.93965530395508
# global step=172032, episodic return=65.56997680664062
# global step=172032, episodic return=49.66027069091797
# global step=174080, episodic return=54.40998840332031
# global step=174080, episodic return=56.05988311767578
# global step=178176, episodic return=58.51383972167969
# global step=178176, episodic return=121.25457000732422
# global step=182272, episodic return=42.6673698425293
# global step=186368, episodic return=141.007568359375
# global step=186368, episodic return=47.069759368896484
# global step=188416, episodic return=109.53760528564453
# global step=190464, episodic return=136.23150634765625
# global step=190464, episodic return=111.40351867675781
# global step=194560, episodic return=72.37865447998047
# global step=196608, episodic return=149.89625549316406
# global step=196608, episodic return=149.9178924560547
# global step=198656, episodic return=45.5519905090332
# global step=204800, episodic return=74.48179626464844
# global step=206848, episodic return=101.16392517089844
# global step=210944, episodic return=86.4147720336914
# global step=221184, episodic return=103.21793365478516
# global step=243712, episodic return=172.27728271484375
# global step=247808, episodic return=102.15341186523438
# global step=264192, episodic return=144.66470336914062
# global step=268288, episodic return=90.20796966552734
# global step=337920, episodic return=198.23361206054688
# global step=339968, episodic return=190.33074951171875
# global step=493568, episodic return=303.2110595703125
# global step=524288, episodic return=332.0247802734375
# global step=538624, episodic return=334.1434631347656
# global step=542720, episodic return=348.79119873046875
# global step=552960, episodic return=343.7350158691406
# global step=565248, episodic return=341.4970703125
# global step=573440, episodic return=362.407958984375
# global step=577536, episodic return=380.8189697265625
# global step=585728, episodic return=361.8466491699219
# global step=589824, episodic return=355.13153076171875
# global step=604160, episodic return=384.5260314941406
# global step=606208, episodic return=361.26544189453125
# global step=610304, episodic return=394.2550964355469
# global step=612352, episodic return=386.2236633300781
# global step=630784, episodic return=389.893310546875
# global step=636928, episodic return=400.9855041503906
# global step=641024, episodic return=408.6220397949219
# global step=643072, episodic return=408.4352722167969
# global step=655360, episodic return=402.68231201171875
# global step=657408, episodic return=401.3227233886719
# global step=657408, episodic return=388.31158447265625
# global step=671744, episodic return=405.9650573730469
# global step=673792, episodic return=352.3486633300781
# global step=675840, episodic return=426.4245910644531
# global step=700416, episodic return=437.33935546875
# global step=704512, episodic return=452.9514465332031
# global step=710656, episodic return=435.0009460449219
# global step=712704, episodic return=431.9900817871094
# global step=718848, episodic return=416.63787841796875
# global step=718848, episodic return=452.7281799316406
# global step=724992, episodic return=426.68804931640625
# global step=733184, episodic return=442.5364685058594
# global step=735232, episodic return=414.215576171875
# global step=735232, episodic return=446.2239074707031
# global step=741376, episodic return=400.81146240234375
# global step=741376, episodic return=452.9309997558594
# global step=745472, episodic return=457.875244140625
# global step=749568, episodic return=441.5275573730469
# global step=751616, episodic return=429.7642517089844
# global step=751616, episodic return=423.5127258300781
# global step=755712, episodic return=422.3306579589844
# global step=761856, episodic return=481.1887512207031
# global step=763904, episodic return=465.2766418457031
# global step=778240, episodic return=467.8437805175781
# global step=778240, episodic return=432.0479736328125
# global step=780288, episodic return=419.96185302734375
# global step=782336, episodic return=459.38873291015625
# global step=784384, episodic return=470.7589416503906
# global step=788480, episodic return=453.77960205078125
# global step=790528, episodic return=472.1532287597656
# global step=800768, episodic return=448.4826354980469
# global step=802816, episodic return=480.6566467285156
# global step=817152, episodic return=494.169677734375
# global step=817152, episodic return=493.63739013671875
# global step=821248, episodic return=478.4738464355469
# global step=825344, episodic return=501.0647888183594
# global step=839680, episodic return=487.6774597167969
# global step=839680, episodic return=446.23406982421875
# global step=847872, episodic return=508.8374938964844
# global step=847872, episodic return=503.1138916015625
# global step=849920, episodic return=444.0546569824219
# global step=849920, episodic return=488.6544189453125
# global step=854016, episodic return=500.912841796875
# global step=862208, episodic return=518.9147338867188
# global step=870400, episodic return=515.9481201171875
# global step=872448, episodic return=488.0287170410156
# global step=874496, episodic return=514.6470947265625
# global step=876544, episodic return=523.5780639648438
# global step=884736, episodic return=510.228515625
# global step=890880, episodic return=538.6143188476562
# global step=890880, episodic return=521.8244018554688
# global step=907264, episodic return=514.4622192382812
# global step=907264, episodic return=479.13470458984375
# global step=909312, episodic return=515.5421142578125
# global step=915456, episodic return=535.1060180664062
# global step=925696, episodic return=522.63037109375
